# %%
import cobra
import pandas as pd
import re
import numpy as np
import scipy.stats as st
from matplotlib import pyplot as plt
from pathlib import Path
import sys
sys.path.append('../../code/')
import leakage, utils
import seaborn as sns
from matplotlib import cm, colors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib
import matplotlib.gridspec as gridspec
import statsmodels.api as sm

# %% [markdown]
# # Read files, define colormap etc

# %%
# df = pd.read_csv('spreadsheet_ecoli_leakage_and_info_230626_owd_significant.csv', index_col = 0)
only_significant_changes = False
timepoints = np.arange(1.5, 18, 1)
knock_outs = False
shadow_price_for_leaked_mets = True


#################
if only_significant_changes:
    s1 = '_osc'
else:
    s1 = ''

if shadow_price_for_leaked_mets:
    s2 = '_SP_for_leaked'
else:
    s2 = ''

if knock_outs:
    s3 = '_KO'
else:
    s3 = ''
    

species = 'c_glutamicum'
timestr = '20230704'
fn = 'spreadsheet_{0}_leakage_{1}{2}{3}{4}.csv'.format(species, timestr, s1, s2, s3)
folder = Path('../../results/{0}/'.format(species))

df = pd.read_csv(folder / fn, index_col = 0)

# %%
# df['log10(Leakage [mmol/gDW/h])'] = df['log10(leakage)']
df['Shadow price [gDW/mmol]'] = df['Shadow price']
df['Topological Polar Surface Area [Å]'] = df['Topological Polar Surface Area []']
# df['log10(-Shadow price [gDW/mmol])'] = df['log10(-Shadow price)']
# df['log10(Turnover [mmol/gDW/h])'] = df['log10(Turnover)']

# %%
cmap40 = colors.ListedColormap(cm.tab20b.colors[4:] + cm.tab20c.colors, name='tab40')
cmap40(34)
# Out:
# (0.7411764705882353, 0.7411764705882353, 0.7411764705882353, 1.0)

# %%
df
# Out:
#                Metabolite name Metabolite id        Mass  Charge  Phosphate  \
# 0    Dihydroxyacetonephosphate          dhap  168.041961    -2.0          1
# 1   Glyceraldehyde-3-phosphate           g3p  168.041961    -2.0          1
# 2         2/3-phosphoglycerate      2pg, 3pg  183.033421    -3.0          1
# 3           Ribose-5-phosphate           r5p  228.093921    -2.0          1
# 4        Erythrose-4-phosphate           e4p  198.067941    -2.0          1
# ..                         ...           ...         ...     ...        ...
# 12                   Glutamate        glu__L  146.121320    -1.0          0
# 13                   Glutamine        gln__L  146.144500     0.0          0
# 14                     Proline        pro__L  115.130460     0.0          0
# 15                      Serine        ser__L  105.092580     0.0          0
# 16                     Glycine           gly   75.066600     0.0          0
#
#     Topological Polar Surface Area []  Concentration  log P  \
# 0                                104.0       0.000374   -2.5
# 1                                104.0            NaN   -2.7
# 2                                124.0       0.001540   -2.6
# 3                                137.0       0.000450   -3.6
# 4                                124.0            NaN   -3.3
# ..                                 ...            ...    ...
# 12                               101.0       0.096000   -3.7
# 13                               106.0       0.003810   -3.1
# 14                                49.3       0.000385   -2.5
# 15                                83.6       0.000068   -3.1
# 16                                63.3            NaN   -3.2
#
#     Leakage (mmol/gDW/h)  Time  ...   Turnover  Median log10(-Shadow price)  \
# 0               0.000424  11.5  ...   4.612112                    -1.486842
# 1               0.000027  11.5  ...  11.037761                    -1.486892
# 2               0.000311  11.5  ...   9.787341                    -1.590262
# 3               0.000032  11.5  ...   1.462941                    -1.228481
# 4                    NaN  11.5  ...        NaN                    -1.339536
# ..                   ...   ...  ...        ...                          ...
# 12                   NaN  23.5  ...        NaN                    -1.131175
# 13                   NaN  23.5  ...        NaN                    -1.107372
# 14                   NaN  23.5  ...        NaN                    -1.037951
# 15              0.000063  23.5  ...   0.001072                    -1.338284
# 16              0.016180  23.5  ...   0.001043                    -1.551070
#
#     Low log10(-Shadow price)  High log10(-Shadow price)  Uptake (mmol/gDW/h)  \
# 0                  -1.255790                  -1.486842         0.000000e+00
# 1                  -1.255790                  -1.486892         0.000000e+00
# 2                  -1.346968                  -1.590262         0.000000e+00
# 3                  -1.038906                  -1.228481         0.000000e+00
# 4                  -1.134555                  -1.339536         5.470538e-05
# ..                       ...                        ...                  ...
# 12                 -1.122470                  -1.592788         1.915781e-03
# 13                 -1.100085                  -1.504036         3.034901e-07
# 14                 -1.020470                  -1.395015                  NaN
# 15                 -1.346173                  -1.215181         0.000000e+00
# 16                 -1.575552                  -1.332464         0.000000e+00
#
#     log10(Leakage [mmol/gDW/h])  log10(-Shadow price [gDW/mmol])  \
# 0                     -3.372943                        -2.053765
# 1                     -4.571600                        -2.053516
# 2                     -3.507142                        -2.026291
# 3                     -4.492419                        -2.088203
# 4                           NaN                              NaN
# ..                          ...                              ...
# 12                          NaN                              NaN
# 13                          NaN                              NaN
# 14                          NaN                              NaN
# 15                    -4.203461                              NaN
# 16                    -1.791026                              NaN
#
#     log10(Turnover [mmol/gDW/h])  Shadow price [gDW/mmol]  \
# 0                       0.663900                -0.008836
# 1                       1.042881                -0.008841
# 2                       0.990665                -0.009413
# 3                       0.165227                -0.008162
# 4                            NaN                      NaN
# ..                           ...                      ...
# 12                           NaN                      NaN
# 13                           NaN                      NaN
# 14                           NaN                      NaN
# 15                     -2.969963                      NaN
# 16                     -2.981728                      NaN
#
#     Topological Polar Surface Area [Å]
# 0                                104.0
# 1                                104.0
# 2                                124.0
# 3                                137.0
# 4                                124.0
# ..                                 ...
# 12                               101.0
# 13                               106.0
# 14                                49.3
# 15                                83.6
# 16                                63.3
#
# [199 rows x 23 columns]

# %% [markdown]
# # Scatterplots and time-traces of specific parameters
# - Shadow price
# - log10(-Shadow price) is [gDW/mM]
# - Turnover
# - log P?
# - Charge?

# %%
hours = np.arange(11.5, 20, 1)

# %%
df.columns
# Out:
# Index(['Metabolite name', 'Metabolite id', 'Mass', 'Charge', 'Phosphate',
#        'Topological Polar Surface Area []', 'Concentration', 'log P',
#        'Leakage (mmol/gDW/h)', 'Time', 'Glucose', 'Predicted growth rate',
#        'Shadow price', 'Turnover', 'Median log10(-Shadow price)',
#        'Low log10(-Shadow price)', 'High log10(-Shadow price)',
#        'Uptake (mmol/gDW/h)', 'log10(Leakage [mmol/gDW/h])',
#        'log10(-Shadow price [gDW/mmol])', 'log10(Turnover [mmol/gDW/h])',
#        'Shadow price [gDW/mmol]', 'Topological Polar Surface Area [Å]'],
#       dtype='object')

# %%
# sns.scatterplot(data = df, x = 'Shadow price', y = 'log10(Leakage [mmol/gDW/h])', hue = 'Time', palette = 'tab20', alpha = 0.9)
sns.scatterplot(data = df.loc[df.Time.isin(hours),:], x = 'log10(-Shadow price [gDW/mmol])', y = 'log10(Leakage [mmol/gDW/h])', hue = 'Time', palette = 'tab20', alpha = 0.9)
# sns.scatterplot(data = df.loc[df.Time.isin(hours),:], x = 'Median log10(-Shadow price)', y = 'log10(Leakage [mmol/gDW/h])', hue = 'Time', palette = 'tab20', alpha = 0.9)
plt.legend(ncol = 2, loc = (1.01, 0))

tmp = df.loc[df.Time.isin(hours),:]
tmp.dropna(inplace = True)
X = sm.add_constant(tmp['log10(-Shadow price [gDW/mmol])'])
smodel = sm.OLS(tmp['log10(Leakage [mmol/gDW/h])'],X)
res = smodel.fit()
# Out:
# /var/folders/h6/4b_zz_cd5d92w2ycp017ytn00000gp/T/ipykernel_17990/75350090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp.dropna(inplace = True)

# %%
np.corrcoef(tmp['log10(-Shadow price [gDW/mmol])'], tmp['log10(Leakage [mmol/gDW/h])'])
tmp.corr()
# Out:
#                                         Mass    Charge  Phosphate  \
# Mass                                1.000000 -0.679305   0.795571
# Charge                             -0.679305  1.000000  -0.893569
# Phosphate                           0.795571 -0.893569   1.000000
# Topological Polar Surface Area []  0.911461 -0.693651   0.720409
# Concentration                      -0.072985 -0.029198  -0.296220
# log P                              -0.245789 -0.111814   0.220490
# Leakage (mmol/gDW/h)               -0.061596  0.534112  -0.303375
# Time                                0.125870 -0.097101   0.121961
# Glucose                            -0.109753  0.083493  -0.097983
# Predicted growth rate              -0.104791  0.084794  -0.097844
# Shadow price                       -0.018872 -0.437736   0.304119
# Turnover                            0.330132 -0.655641   0.509998
# Median log10(-Shadow price)         0.156016  0.362508  -0.179659
# Low log10(-Shadow price)            0.080517  0.611878  -0.420850
# High log10(-Shadow price)           0.344228  0.335554  -0.012546
# Uptake (mmol/gDW/h)                      NaN       NaN        NaN
# log10(Leakage [mmol/gDW/h])        -0.401086  0.617897  -0.568671
# log10(-Shadow price [gDW/mmol])     0.023387  0.327490  -0.252648
# log10(Turnover [mmol/gDW/h])        0.427032 -0.792201   0.607488
# Shadow price [gDW/mmol]            -0.018872 -0.437736   0.304119
# Topological Polar Surface Area [Å]  0.911461 -0.693651   0.720409
#
#                                     Topological Polar Surface Area []  \
# Mass                                                          0.911461
# Charge                                                       -0.693651
# Phosphate                                                     0.720409
# Topological Polar Surface Area []                            1.000000
# Concentration                                                 0.049846
# log P                                                        -0.343017
# Leakage (mmol/gDW/h)                                         -0.121195
# Time                                                          0.110850
# Glucose                                                      -0.084451
# Predicted growth rate                                        -0.088177
# Shadow price                                                  0.110827
# Turnover                                                      0.419027
# Median log10(-Shadow price)                                   0.000865
# Low log10(-Shadow price)                                     -0.130230
# High log10(-Shadow price)                                     0.130956
# Uptake (mmol/gDW/h)                                                NaN
# log10(Leakage [mmol/gDW/h])                                  -0.419436
# log10(-Shadow price [gDW/mmol])                              -0.071664
# log10(Turnover [mmol/gDW/h])                                  0.586803
# Shadow price [gDW/mmol]                                       0.110827
# Topological Polar Surface Area [Å]                            1.000000
#
#                                     Concentration     log P  \
# Mass                                    -0.072985 -0.245789
# Charge                                  -0.029198 -0.111814
# Phosphate                               -0.296220  0.220490
# Topological Polar Surface Area []       0.049846 -0.343017
# Concentration                            1.000000 -0.612682
# log P                                   -0.612682  1.000000
# Leakage (mmol/gDW/h)                    -0.101797 -0.031849
# Time                                     0.018554  0.036449
# Glucose                                 -0.038822 -0.022539
# Predicted growth rate                   -0.043606 -0.025240
# Shadow price                            -0.008332  0.163938
# Turnover                                 0.131842  0.185172
# Median log10(-Shadow price)             -0.062470 -0.199415
# Low log10(-Shadow price)                 0.039427 -0.339632
# High log10(-Shadow price)               -0.317900 -0.131563
# Uptake (mmol/gDW/h)                           NaN       NaN
# log10(Leakage [mmol/gDW/h])              0.217829 -0.017636
# log10(-Shadow price [gDW/mmol])          0.062063 -0.129537
# log10(Turnover [mmol/gDW/h])             0.267690 -0.061094
# Shadow price [gDW/mmol]                 -0.008332  0.163938
# Topological Polar Surface Area [Å]       0.049846 -0.343017
#
#                                     Leakage (mmol/gDW/h)      Time   Glucose  \
# Mass                                           -0.061596  0.125870 -0.109753
# Charge                                          0.534112 -0.097101  0.083493
# Phosphate                                      -0.303375  0.121961 -0.097983
# Topological Polar Surface Area []             -0.121195  0.110850 -0.084451
# Concentration                                  -0.101797  0.018554 -0.038822
# log P                                          -0.031849  0.036449 -0.022539
# Leakage (mmol/gDW/h)                            1.000000 -0.009098 -0.006392
# Time                                           -0.009098  1.000000 -0.811044
# Glucose                                        -0.006392 -0.811044  1.000000
# Predicted growth rate                           0.004940 -0.803146  0.960093
# Shadow price                                   -0.448047 -0.560008  0.657209
# Turnover                                       -0.231178 -0.254090  0.308670
# Median log10(-Shadow price)                     0.447915  0.501005 -0.575063
# Low log10(-Shadow price)                        0.585259  0.018458 -0.029485
# High log10(-Shadow price)                       0.586624  0.023176  0.025839
# Uptake (mmol/gDW/h)                                  NaN       NaN       NaN
# log10(Leakage [mmol/gDW/h])                     0.769690 -0.082108  0.064875
# log10(-Shadow price [gDW/mmol])                 0.307947  0.598429 -0.717833
# log10(Turnover [mmol/gDW/h])                   -0.437892 -0.252707  0.289907
# Shadow price [gDW/mmol]                        -0.448047 -0.560008  0.657209
# Topological Polar Surface Area [Å]             -0.121195  0.110850 -0.084451
#
#                                     Predicted growth rate  ...  Turnover  \
# Mass                                            -0.104791  ...  0.330132
# Charge                                           0.084794  ... -0.655641
# Phosphate                                       -0.097844  ...  0.509998
# Topological Polar Surface Area []              -0.088177  ...  0.419027
# Concentration                                   -0.043606  ...  0.131842
# log P                                           -0.025240  ...  0.185172
# Leakage (mmol/gDW/h)                             0.004940  ... -0.231178
# Time                                            -0.803146  ... -0.254090
# Glucose                                          0.960093  ...  0.308670
# Predicted growth rate                            1.000000  ...  0.324246
# Shadow price                                     0.642757  ...  0.524585
# Turnover                                         0.324246  ...  1.000000
# Median log10(-Shadow price)                     -0.583999  ... -0.539250
# Low log10(-Shadow price)                        -0.017085  ... -0.513633
# High log10(-Shadow price)                        0.012310  ... -0.352822
# Uptake (mmol/gDW/h)                                   NaN  ...       NaN
# log10(Leakage [mmol/gDW/h])                      0.091869  ... -0.107622
# log10(-Shadow price [gDW/mmol])                 -0.680423  ... -0.532980
# log10(Turnover [mmol/gDW/h])                     0.323198  ...  0.771893
# Shadow price [gDW/mmol]                          0.642757  ...  0.524585
# Topological Polar Surface Area [Å]              -0.088177  ...  0.419027
#
#                                     Median log10(-Shadow price)  \
# Mass                                                   0.156016
# Charge                                                 0.362508
# Phosphate                                             -0.179659
# Topological Polar Surface Area []                     0.000865
# Concentration                                         -0.062470
# log P                                                 -0.199415
# Leakage (mmol/gDW/h)                                   0.447915
# Time                                                   0.501005
# Glucose                                               -0.575063
# Predicted growth rate                                 -0.583999
# Shadow price                                          -0.907380
# Turnover                                              -0.539250
# Median log10(-Shadow price)                            1.000000
# Low log10(-Shadow price)                               0.682191
# High log10(-Shadow price)                              0.672002
# Uptake (mmol/gDW/h)                                         NaN
# log10(Leakage [mmol/gDW/h])                            0.279255
# log10(-Shadow price [gDW/mmol])                        0.850332
# log10(Turnover [mmol/gDW/h])                          -0.614432
# Shadow price [gDW/mmol]                               -0.907380
# Topological Polar Surface Area [Å]                     0.000865
#
#                                     Low log10(-Shadow price)  \
# Mass                                                0.080517
# Charge                                              0.611878
# Phosphate                                          -0.420850
# Topological Polar Surface Area []                 -0.130230
# Concentration                                       0.039427
# log P                                              -0.339632
# Leakage (mmol/gDW/h)                                0.585259
# Time                                                0.018458
# Glucose                                            -0.029485
# Predicted growth rate                              -0.017085
# Shadow price                                       -0.668569
# Turnover                                           -0.513633
# Median log10(-Shadow price)                         0.682191
# Low log10(-Shadow price)                            1.000000
# High log10(-Shadow price)                           0.790196
# Uptake (mmol/gDW/h)                                      NaN
# log10(Leakage [mmol/gDW/h])                         0.451080
# log10(-Shadow price [gDW/mmol])                     0.540463
# log10(Turnover [mmol/gDW/h])                       -0.662904
# Shadow price [gDW/mmol]                            -0.668569
# Topological Polar Surface Area [Å]                 -0.130230
#
#                                     High log10(-Shadow price)  \
# Mass                                                 0.344228
# Charge                                               0.335554
# Phosphate                                           -0.012546
# Topological Polar Surface Area []                   0.130956
# Concentration                                       -0.317900
# log P                                               -0.131563
# Leakage (mmol/gDW/h)                                 0.586624
# Time                                                 0.023176
# Glucose                                              0.025839
# Predicted growth rate                                0.012310
# Shadow price                                        -0.537849
# Turnover                                            -0.352822
# Median log10(-Shadow price)                          0.672002
# Low log10(-Shadow price)                             0.790196
# High log10(-Shadow price)                            1.000000
# Uptake (mmol/gDW/h)                                       NaN
# log10(Leakage [mmol/gDW/h])                          0.234187
# log10(-Shadow price [gDW/mmol])                      0.418012
# log10(Turnover [mmol/gDW/h])                        -0.503983
# Shadow price [gDW/mmol]                             -0.537849
# Topological Polar Surface Area [Å]                   0.130956
#
#                                     Uptake (mmol/gDW/h)  \
# Mass                                                NaN
# Charge                                              NaN
# Phosphate                                           NaN
# Topological Polar Surface Area []                  NaN
# Concentration                                       NaN
# log P                                               NaN
# Leakage (mmol/gDW/h)                                NaN
# Time                                                NaN
# Glucose                                             NaN
# Predicted growth rate                               NaN
# Shadow price                                        NaN
# Turnover                                            NaN
# Median log10(-Shadow price)                         NaN
# Low log10(-Shadow price)                            NaN
# High log10(-Shadow price)                           NaN
# Uptake (mmol/gDW/h)                                 NaN
# log10(Leakage [mmol/gDW/h])                         NaN
# log10(-Shadow price [gDW/mmol])                     NaN
# log10(Turnover [mmol/gDW/h])                        NaN
# Shadow price [gDW/mmol]                             NaN
# Topological Polar Surface Area [Å]                  NaN
#
#                                     log10(Leakage [mmol/gDW/h])  \
# Mass                                                  -0.401086
# Charge                                                 0.617897
# Phosphate                                             -0.568671
# Topological Polar Surface Area []                    -0.419436
# Concentration                                          0.217829
# log P                                                 -0.017636
# Leakage (mmol/gDW/h)                                   0.769690
# Time                                                  -0.082108
# Glucose                                                0.064875
# Predicted growth rate                                  0.091869
# Shadow price                                          -0.358208
# Turnover                                              -0.107622
# Median log10(-Shadow price)                            0.279255
# Low log10(-Shadow price)                               0.451080
# High log10(-Shadow price)                              0.234187
# Uptake (mmol/gDW/h)                                         NaN
# log10(Leakage [mmol/gDW/h])                            1.000000
# log10(-Shadow price [gDW/mmol])                        0.237637
# log10(Turnover [mmol/gDW/h])                          -0.345432
# Shadow price [gDW/mmol]                               -0.358208
# Topological Polar Surface Area [Å]                    -0.419436
#
#                                     log10(-Shadow price [gDW/mmol])  \
# Mass                                                       0.023387
# Charge                                                     0.327490
# Phosphate                                                 -0.252648
# Topological Polar Surface Area []                        -0.071664
# Concentration                                              0.062063
# log P                                                     -0.129537
# Leakage (mmol/gDW/h)                                       0.307947
# Time                                                       0.598429
# Glucose                                                   -0.717833
# Predicted growth rate                                     -0.680423
# Shadow price                                              -0.914900
# Turnover                                                  -0.532980
# Median log10(-Shadow price)                                0.850332
# Low log10(-Shadow price)                                   0.540463
# High log10(-Shadow price)                                  0.418012
# Uptake (mmol/gDW/h)                                             NaN
# log10(Leakage [mmol/gDW/h])                                0.237637
# log10(-Shadow price [gDW/mmol])                            1.000000
# log10(Turnover [mmol/gDW/h])                              -0.564573
# Shadow price [gDW/mmol]                                   -0.914900
# Topological Polar Surface Area [Å]                        -0.071664
#
#                                     log10(Turnover [mmol/gDW/h])  \
# Mass                                                    0.427032
# Charge                                                 -0.792201
# Phosphate                                               0.607488
# Topological Polar Surface Area []                      0.586803
# Concentration                                           0.267690
# log P                                                  -0.061094
# Leakage (mmol/gDW/h)                                   -0.437892
# Time                                                   -0.252707
# Glucose                                                 0.289907
# Predicted growth rate                                   0.323198
# Shadow price                                            0.667240
# Turnover                                                0.771893
# Median log10(-Shadow price)                            -0.614432
# Low log10(-Shadow price)                               -0.662904
# High log10(-Shadow price)                              -0.503983
# Uptake (mmol/gDW/h)                                          NaN
# log10(Leakage [mmol/gDW/h])                            -0.345432
# log10(-Shadow price [gDW/mmol])                        -0.564573
# log10(Turnover [mmol/gDW/h])                            1.000000
# Shadow price [gDW/mmol]                                 0.667240
# Topological Polar Surface Area [Å]                      0.586803
#
#                                     Shadow price [gDW/mmol]  \
# Mass                                              -0.018872
# Charge                                            -0.437736
# Phosphate                                          0.304119
# Topological Polar Surface Area []                 0.110827
# Concentration                                     -0.008332
# log P                                              0.163938
# Leakage (mmol/gDW/h)                              -0.448047
# Time                                              -0.560008
# Glucose                                            0.657209
# Predicted growth rate                              0.642757
# Shadow price                                       1.000000
# Turnover                                           0.524585
# Median log10(-Shadow price)                       -0.907380
# Low log10(-Shadow price)                          -0.668569
# High log10(-Shadow price)                         -0.537849
# Uptake (mmol/gDW/h)                                     NaN
# log10(Leakage [mmol/gDW/h])                       -0.358208
# log10(-Shadow price [gDW/mmol])                   -0.914900
# log10(Turnover [mmol/gDW/h])                       0.667240
# Shadow price [gDW/mmol]                            1.000000
# Topological Polar Surface Area [Å]                 0.110827
#
#                                     Topological Polar Surface Area [Å]
# Mass                                                          0.911461
# Charge                                                       -0.693651
# Phosphate                                                     0.720409
# Topological Polar Surface Area []                            1.000000
# Concentration                                                 0.049846
# log P                                                        -0.343017
# Leakage (mmol/gDW/h)                                         -0.121195
# Time                                                          0.110850
# Glucose                                                      -0.084451
# Predicted growth rate                                        -0.088177
# Shadow price                                                  0.110827
# Turnover                                                      0.419027
# Median log10(-Shadow price)                                   0.000865
# Low log10(-Shadow price)                                     -0.130230
# High log10(-Shadow price)                                     0.130956
# Uptake (mmol/gDW/h)                                                NaN
# log10(Leakage [mmol/gDW/h])                                  -0.419436
# log10(-Shadow price [gDW/mmol])                              -0.071664
# log10(Turnover [mmol/gDW/h])                                  0.586803
# Shadow price [gDW/mmol]                                       0.110827
# Topological Polar Surface Area [Å]                            1.000000
#
# [21 rows x 21 columns]

# %%
ax = sns.scatterplot(data = df, x = 'log10(-Shadow price [gDW/mmol])', y = 'log10(Leakage [mmol/gDW/h])', 
                     hue = 'Metabolite name', alpha = 0.8, palette = 'tab20b', s = 80) # .loc[df.Time.isin([5.5, 6.5, 7.5, 8.5]),:]
ax.legend(ncol = 2, loc = (1.01, 0))

# %%
fig, ax = plt.subplots(1)
hours = np.arange(1.5,15,1)
x = 'log10(-Shadow price [gDW/mmol])'
y = 'log10(Leakage [mmol/gDW/h])'
# corr = []
mnames = df.loc[df.Time.isin(hours), 'Metabolite name'].unique()

for j, m in enumerate(mnames):
    dfm = df.loc[df['Metabolite name']==m,:]
    ax.plot(dfm[x], dfm[y], c = cmap40(j), marker = 'o')
    # ax.scatter(dfm[x], dfm[y], c = cmap40(j))
    # print(dfm)

patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
l1 = plt.legend(handles=patches, ncol = 2, loc = (1.05,0), title = 'Metabolite')

plt.xlabel(x)
plt.ylabel(y)
# Out:
# Text(0, 0.5, 'log10(Leakage [mmol/gDW/h])')

# %%
df['Predicted growth rate'].unique()
# Out:
# array([0.04726538, 0.45325204, 0.4775928 , 0.46568768, 0.28614336,
#        0.60310813, 0.34427639, 0.30232154, 0.04109902])

# %%
hours
# Out:
# array([ 3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5,
#        14.5])

# %%
fig, ax = plt.subplots(1)
hours = [5.5, 6.5, 7.5, 8.5]
x = 'Shadow price [gDW/mmol]'
x = 'log10(-Shadow price [gDW/mmol])'
y = 'log10(Leakage [mmol/gDW/h])'
symbols = ['o', 's', 'v', 'D']
corr = []
mnames = df.loc[df.Time.isin(hours), 'Metabolite name'].unique()
for i, t in enumerate(hours):
    x_arr = df.loc[df.Time==t, x]
    y_arr = df.loc[df.Time==t, y]
    l_arr = df.loc[df.Time==t, 'Metabolite name']
    xy_corr = []
    for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
        if not np.isnan(yj) and not np.isnan(xj):
            xy_corr.append([xj,yj])
            ax.scatter(xj, yj, marker = symbols[i], color = cmap40(j), label = l_arr[j])
        else:
            print(t, l_arr[j])
    corr.append(st.pearsonr([x[0] for x in xy_corr],[x[1] for x in xy_corr]))
patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
patches2 = [mlines.Line2D([], [], color='k', marker=m, linestyle='None',
                          markersize=8, label=t) for m,t in zip(symbols, hours)]
l1 = plt.legend(handles=patches, ncol = 2, loc = (1.05,0), title = 'Metabolite')
plt.legend(handles=patches2, ncol = 23, loc = (0,1.05), title = 'Time [h]')
plt.gca().add_artist(l1)

plt.xlabel(x)
plt.ylabel(y)
# Out:
# 5.5 Alanine
# 5.5 Lysine
# 5.5 Serine
# 5.5 Glycine
# 5.5 Arginine
# 5.5 Histidine
# 5.5 Orotate
# 6.5 Lysine
# 6.5 Tryptophane
# 6.5 Tyrosine
# 6.5 Proline
# 6.5 Glycine
# 6.5 Arginine
# 6.5 Histidine
# 7.5 Lysine
# 7.5 Glutamine
# 7.5 Proline
# 7.5 Serine
# 7.5 Glycine
# 7.5 Histidine
# 8.5 Glyceraldehyde-3-phosphate
# 8.5 Pyruvate
# 8.5 alpha-ketoglutarate
# 8.5 Fumarate
# 8.5 Alanine
# 8.5 Lysine
# 8.5 Glutamate
# 8.5 Proline
# 8.5 Serine
# 8.5 Glycine
# 8.5 Arginine
# 8.5 Histidine
# Text(0, 0.5, 'log10(Leakage [mmol/gDW/h])')

# %% [markdown]
# # Correlations between lekage rates and chosen parameters

# %%
import matplotlib.gridspec as gridspec
import statsmodels.api as sm

# Create 2x2 sub plots
gs = gridspec.GridSpec(2, 2)

fig = plt.figure(figsize = (14, 10))
ax1 = fig.add_subplot(gs[0, 0]) # row 0, col 0
ax2 = fig.add_subplot(gs[0, 1]) # row 0, col 1
ax3 = fig.add_subplot(gs[1, 0]) # row 1, span all columns

axes = [ax1,ax2,ax3]
# fig, axes = plt.subplots(2,2, )
# axes = axes.flatten()
hours = np.array([5.5, 6.5, 7.5])-4
# x = 'log10(Turnover)'
x = 'log10(-Shadow price [gDW/mmol])'
y = 'log10(Leakage [mmol/gDW/h])'
symbols = ['o', 's', 'v', 'D']
corr = []
mnames = df.loc[df.Time.isin(hours), 'Metabolite name'].unique()
for i, t in enumerate(hours):
    x_arr = df.loc[df.Time==t, x]
    y_arr = df.loc[df.Time==t, y]
    l_arr = df.loc[df.Time==t, 'Metabolite name']
    xc = []
    yc = []
    for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
        if np.isfinite(yj) and np.isfinite(xj):
            xc.append(xj)
            yc.append(yj)
            axes[i].scatter(xj, yj, color = cmap40(j), label = l_arr[j], s = 100)#marker = symbols[i]
        else:
            print(t, l_arr[j],j, xj, yj)
    rho, pval = st.pearsonr(xc,yc)
    corr.append((rho, pval))
    
    axes[i].text(0.99, 0.95, 'ρ = {0:.2f}, p-value = {1:.4f}'.format(rho, pval),
     horizontalalignment='right',
     verticalalignment='top',
     transform = axes[i].transAxes)
    axes[i].set_title('Time: {0} h'.format(t))
    axes[i].set_xlabel(x)
    axes[i].set_ylabel(y)
    sns.regplot(x=x_arr, y = y_arr, ax = axes[i], scatter = False, color = 'k', ci = 95)
    
    X = sm.add_constant(xc)
    model = sm.OLS(yc, X)
    res = model.fit()
    # print(res.summary())
    axes[i].text(0.99, 0.9, 'y = {0:.2f}x {1:0.2f}, R2: {2:.2f}'.format(res.params[0], res.params[1], res.rsquared),
     horizontalalignment='right', verticalalignment='top', transform = axes[i].transAxes)
    
patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
# patches2 = [mlines.Line2D([], [], color='k', marker=m, linestyle='None',
                          # markersize=8, label=t) for m,t in zip(symbols, hours)]
l1 = plt.legend(handles=patches, ncol = 3, loc = (1.05,0), title = 'Metabolite')
# plt.legend(handles=patches2, ncol = 23, loc = (0,1.05), title = 'Time [h]')
# plt.gca().add_artist(l1)

# plt.xlabel(x)
# plt.ylabel(y)
# plt.tight_layout()
# Out:
# 1.5 alpha-ketoglutarate 9 nan -inf
# 1.5 Leucine/Isoleucine 12 nan nan
# 1.5 Tryptophane 17 nan nan
# 1.5 Tyrosine 18 nan nan
# 1.5 Glutamate 20 nan nan
# 1.5 Histidine 25 nan nan
# 1.5 Orotate 27 nan nan
# 2.5 Citrate 7 nan nan
# 2.5 alpha-ketoglutarate 9 nan -inf
# 2.5 Leucine/Isoleucine 12 nan nan
# 2.5 Valine 13 nan nan
# 2.5 Tryptophane 17 nan nan
# 2.5 Serine 23 nan nan
# 2.5 Arginine 25 nan nan
# 2.5 Histidine 26 nan nan
# 2.5 Uracil 28 nan nan
# 3.5 Pyruvate 4 nan nan
# 3.5 alpha-ketoglutarate 9 nan -inf
# 3.5 Fumarate 10 nan nan
# 3.5 Tryptophane 17 nan nan
# 3.5 Tyrosine 18 nan nan
# 3.5 Serine 23 nan nan
# 3.5 Arginine 25 nan nan
# 3.5 Histidine 26 nan nan
# 3.5 Orotate 28 nan nan

# %%
import matplotlib.gridspec as gridspec
import statsmodels.api as sm

# Create 2x2 sub plots
gs = gridspec.GridSpec(2, 2)

fig = plt.figure(figsize = (14, 10))
ax1 = fig.add_subplot(gs[0, 0]) # row 0, col 0
ax2 = fig.add_subplot(gs[0, 1]) # row 0, col 1
ax3 = fig.add_subplot(gs[1, 0]) # row 1, span all columns
axes = [ax1,ax2,ax3]
# fig, axes = plt.subplots(2,2, )
# axes = axes.flatten()
hours = np.array([6.5, 7.5, 8.5])-2
# x = 'Shadow price [gDW/mmol]'
# x = 'Charge'
# x = 'log10(Turnover)'
# y = 'log10(Leakage [mmol/gDW/h])'
y = ''
symbols = ['o', 's', 'v', 'D']
corr = []
mnames = df.loc[df.Time.isin(hours), 'Metabolite name'].unique()
for i, t in enumerate(hours):
    x_arr = df.loc[df.Time==t, x]
    y_arr = df.loc[df.Time==t, y]
    l_arr = df.loc[df.Time==t, 'Metabolite name']
    xc = []
    yc = []
    for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
        if np.isfinite(yj) and np.isfinite(xj):
            xc.append(xj)
            yc.append(yj)
            axes[i].scatter(xj, yj, color = cmap40(j), label = l_arr[j], s = 100)#marker = symbols[i]
        else:
            print(t, l_arr[j], j, xj, yj)
    rho, pval = st.pearsonr(xc,yc)
    corr.append((rho, pval))
    
    axes[i].text(0.99, 0.95, 'ρ = {0:.2f}, p-value = {1:.4f}'.format(rho, pval),
     horizontalalignment='right',
     verticalalignment='top',
     transform = axes[i].transAxes)
    axes[i].set_title('Time: {0} h'.format(t))
    axes[i].set_xlabel(x)
    axes[i].set_ylabel(y)
    sns.regplot(x=x_arr, y = y_arr, ax = axes[i], scatter = False, color = 'k', ci = 95)
    
    X = sm.add_constant(xc)
    model = sm.OLS(yc, X)
    res = model.fit()
    # print(res.summary())
    axes[i].text(0.99, 0.9, 'y = {0:.2f}x {1:0.2f}, $R^2$: {2:.2f}'.format(res.params[0], res.params[1], res.rsquared),
     horizontalalignment='right', verticalalignment='top', transform = axes[i].transAxes)
    
patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
# patches2 = [mlines.Line2D([], [], color='k', marker=m, linestyle='None',
                          # markersize=8, label=t) for m,t in zip(symbols, hours)]
l1 = plt.legend(handles=patches, ncol = 3, loc = (1.05,0), title = 'Metabolite')
# plt.legend(handles=patches2, ncol = 23, loc = (0,1.05), title = 'Time [h]')
# plt.gca().add_artist(l1)

# plt.xlabel(x)
# plt.ylabel(y)
# plt.tight_layout()
# Out:
# 4.5 Lysine 17 nan -inf
# 4.5 Tryptophane 18 nan nan
# 4.5 Tyrosine 19 nan nan
# 4.5 Proline 23 nan nan
# 4.5 Serine 24 nan nan
# 4.5 Glycine 25 nan nan
# 4.5 Histidine 27 nan nan
# 4.5 Uracil 30 nan nan
# 5.5 Alanine 11 nan nan
# 5.5 Lysine 17 nan -inf
# 5.5 Serine 24 nan nan
# 5.5 Glycine 25 nan nan
# 5.5 Arginine 26 nan nan
# 5.5 Histidine 27 nan nan
# 5.5 Orotate 29 nan nan
# 6.5 Lysine 17 nan -inf
# 6.5 Tryptophane 18 nan nan
# 6.5 Tyrosine 19 nan nan
# 6.5 Proline 23 nan nan
# 6.5 Glycine 25 nan nan
# 6.5 Arginine 26 nan nan
# 6.5 Histidine 27 nan nan

# %% [markdown]
# # All correlations

# %%
cols_for_corr = ['Mass',
       'Charge', 'Phosphate', 'Topological Polar Surface Area [Å]',
       # 'Shadow price [gDW/mmol]',
                 'log10(-Shadow price [gDW/mmol])',
       'log10(Turnover [mmol/gDW/h])', 'log P']

# %% [markdown]
# ## "timecourse" for correlations for all parameters

# %%
# Create 2x2 sub plots
fig, axes = plt.subplots(2,2, figsize = (10,6))
[ax1,ax2,ax3, ax4] = axes.flatten()
hours = df.Time.unique()
y = 'log10(Leakage [mmol/gDW/h])'
p_val_lim = 0.01
for i, c in enumerate(cols_for_corr):
    corr = []
    pvals = np.zeros(len(hours))*np.nan
    rhos = np.zeros(len(hours))*np.nan
    r2s = np.zeros(len(hours))*np.nan
    for k, h in enumerate(hours):
        dft = df.loc[df.Time==h, [c, y]]
        x_arr = dft[c]
        y_arr = dft[y]
        
        xc = []
        yc = []
        for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
            if np.isfinite(yj) and np.isfinite(xj):
                xc.append(xj)
                yc.append(yj)
        if not len(xc):
            continue
        rho, pvals[k] = st.pearsonr(xc,yc)

        X = sm.add_constant(xc)
        model = sm.OLS(yc, X)
        res = model.fit()
        
        if np.abs(rho) == 0:
            rhos[k] = np.nan
            r2s[k] = np.nan 
        else:
            if pvals[k] < p_val_lim:
                rhos[k] = rho
                r2s[k] = res.rsquared
            else:
                rhos[k] = np.nan
                r2s[k] = np.nan   
        
    ax1.scatter(hours, rhos, label = c, s = 70, alpha = 0.8)
    ax2.scatter(hours, pvals,label = c, s = 70, alpha = 0.8)
    ax3.scatter(hours, r2s, label = c, s = 70, alpha = 0.8)
    
ax2.axhline(p_val_lim, c = 'k', ls = '--', zorder = -1)
for ax in [ax1,ax2,ax3]:
    ax.set_xlabel('Time [h]', fontdict = {'size':14})
    ax.tick_params(axis='both', which='major', labelsize=14)
ax1.set_ylabel('Pearson correlation', fontdict = {'size':14})
ax2.set_yscale('log')
ax2.set_ylabel('p-value', fontdict = {'size':14})
ax3.set_ylabel('$R^2$', fontdict = {'size':14})
ax3.set_ylim(0,1)
ax2.legend(loc='upper left', bbox_to_anchor=(0., -0.4), ncol = 1)
ax2.set_title('p-values from Pearson correlations', fontdict = {'size':14})
ax1.set_title('Significant Pearson correlations (p-value <{0}'.format(p_val_lim), fontdict = {'size':14})
ax3.set_title('$R^2$ for a linear model predicting leakage rates', fontdict = {'size':14})
ax4.set_axis_off()

plt.subplots_adjust(hspace = 0.6, wspace = 0.3)
# patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
# # patches2 = [mlines.Line2D([], [], color='k', marker=m, linestyle='None',
#                           # markersize=8, label=t) for m,t in zip(symbols, hours)]
# l1 = axes[N-1].legend(handles=patches, ncol = 3, loc = (1.05,0), title = 'Metabolite')
# plt.tight_layout()
# Out:
# /Users/ssulheim/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/ssulheim/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
# Create 2x2 sub plots
fig, ax1 = plt.subplots(1,1, figsize = (10,6))
# [ax1,ax2,ax3, ax4] = axes.flatten()
hours = df.Time.unique()
y = 'log10(Leakage [mmol/gDW/h])'
p_val_lim = 0.01
for i, c in enumerate(cols_for_corr):
    corr = []
    pvals = np.zeros(len(hours))
    rhos = np.zeros(len(hours))
    r2s = np.zeros(len(hours))
    for k, h in enumerate(hours):
        dft = df.loc[df.Time==h, [c, y]]
        x_arr = dft[c]
        y_arr = dft[y]
        
        xc = []
        yc = []
        for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
            if np.isfinite(yj) and np.isfinite(xj):
                xc.append(xj)
                yc.append(yj)
                
        rho, pvals[k] = st.pearsonr(xc,yc)
        rhos[k] = rho
        # X = sm.add_constant(xc)
        # model = sm.OLS(yc, X)
        # res = model.fit()
    ax1.scatter(rhos, pvals,label = c, s = 70, alpha = 0.8)
    ax1.set_yscale('log')
    ax1.axhline(0.01, c = 'k', ls = '--')
    plt.legend()

# %%
df.columns
# Out:
# Index(['Metabolite name', 'Metabolite id', 'Mass', 'Charge', 'Phosphate',
#        'Topological Polar Surface Area []', 'Concentration', 'log P',
#        'Leakage (mmol/gDW/h)', 'Time', 'Glucose', 'Predicted growth rate',
#        'Shadow price', 'Turnover', 'Uptake (mmol/gDW/h)',
#        'log10(Leakage [mmol/gDW/h])', 'log10(-Shadow price [gDW/mmol])',
#        'log10(Turnover [mmol/gDW/h])', 'Shadow price [gDW/mmol]',
#        'Topological Polar Surface Area [Å]'],
#       dtype='object')

# %%
# Create 2x2 sub plots
N = len(cols_for_corr)
gs = gridspec.GridSpec(3, 3)
fig = plt.figure(figsize = (16, 12))
axes = []
l = 0 
for i in range(3):
    for j in range(3):
        if i*3+j >=N:
            break
        axes.append(fig.add_subplot(gs[i, j])) # row 0, col 0
dft = df.loc[df.Time==7.5, cols_for_corr+['Metabolite name', 'log10(Leakage [mmol/gDW/h])']]
# dft = dft0.loc[~dft0.isna().any(axis =1),:]
l_arr = dft['Metabolite name'].unique()
y_arr = dft['log10(Leakage [mmol/gDW/h])']

corr = []
for i, c in enumerate(cols_for_corr):
    ax = axes[i]
    x_arr = dft[c]
    xy_corr = []
    for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
        if np.isfinite(yj) and np.isfinite(xj):
            xy_corr.append([xj,yj])
        ax.scatter(xj, yj, color = cmap40(j), label = l_arr[j], s = 100)#marker = symbols[i]
    xc = [x[0] for x in xy_corr]
    yc = [x[1] for x in xy_corr]
    # print(xc, yc)
    rho, pval = st.pearsonr(xc,yc)
    # rho, pval = st.pearsonr(x_arr, y_arr)
    corr.append((rho, pval))
    
    axes[i].text(0.99, 0.95, 'ρ = {0:.2f}, p-value = {1:.4f}'.format(rho, pval),
     horizontalalignment='right',
     verticalalignment='top',
     transform = axes[i].transAxes,  fontdict={'size': 12})
    sns.regplot(x=xc, y = yc, ax = axes[i], scatter = False, color = 'k', ci = 95)
    
    X = sm.add_constant(xc)
    model = sm.OLS(yc, X)
    res = model.fit()
    # print(res.summary())
    axes[i].text(0.99, 0.9, r'y = {0:.2e}x {1:0.2e}, $R^2$: {2:.2f}'.format(res.params[0], res.params[1], res.rsquared),
     horizontalalignment='right', verticalalignment='top', transform = axes[i].transAxes, fontdict={'size': 12})
    
    ax.set_xlabel(c,  fontdict={'size': 12})
    ax.set_ylabel('log10(leakage [mmol/gDW/h])',  fontdict={'size': 12})
    ax.tick_params(axis='both', which='major', labelsize=12)
patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
# patches2 = [mlines.Line2D([], [], color='k', marker=m, linestyle='None',
                          # markersize=8, label=t) for m,t in zip(symbols, hours)]
l1 = axes[N-1].legend(handles=patches, ncol = 3, loc = (1.05,0), title = 'Metabolite')
# plt.tight_layout()

# %%
# Create 2x2 sub plots
N = len(cols_for_corr)
gs = gridspec.GridSpec(3, 3)
fig = plt.figure(figsize = (16, 12))
axes = []
l = 0 
for i in range(3):
    for j in range(3):
        if i*3+j >=N:
            break
        axes.append(fig.add_subplot(gs[i, j])) # row 0, col 0
dft = df.loc[df.Time.isin([5.5, 6.5, 7.5, 8.5, 9.5, 10.5]), cols_for_corr+['Metabolite name', 'log10(leakage [mmol/gDW/h])']]
# dft = dft0.loc[~dft0.isna().any(axis =1),:]
l_arr = list(dft['Metabolite name'])
y_arr = dft['log10(leakage [mmol/gDW/h])']

corr = []
for i, c in enumerate(cols_for_corr):
    ax = axes[i]
    x_arr = dft[c]
    xy_corr = []
    for j, (xj,yj) in enumerate(zip(x_arr, y_arr)):
        if np.isfinite(yj) and np.isfinite(xj):
            xy_corr.append([xj,yj])
            # print(l_arr[j])
            ax.scatter(xj, yj, color = cmap40(j), label = l_arr[j], s = 100)#marker = symbols[i]
    xc = [x[0] for x in xy_corr]
    yc = [x[1] for x in xy_corr]
    
    rho, pval = st.pearsonr(xc,yc)
    # rho, pval = st.pearsonr(x_arr, y_arr)
    corr.append((rho, pval))
    
    axes[i].text(0.99, 0.95, 'ρ = {0:.2f}, p-value = {1:.4f}'.format(rho, pval),
     horizontalalignment='right',
     verticalalignment='top',
     transform = axes[i].transAxes)
    sns.regplot(x=x_arr, y = y_arr, ax = axes[i], scatter = False, color = 'k', ci = 95)
    
    X = sm.add_constant(xc)
    model = sm.OLS(yc, X)
    res = model.fit()
    # print(res.summary())
    axes[i].text(0.99, 0.9, r'y = {0:.2e}x {1:0.2e}, $R^2$: {2:.2f}'.format(res.params[0], res.params[1], res.rsquared),
     horizontalalignment='right', verticalalignment='top', transform = axes[i].transAxes)
    
    ax.set_xlabel(c)
    ax.set_ylabel('log10(leakage [mmol/gDW/h])')
    
patches = [mpatches.Patch(color=cmap40(k), label=mnames[k]) for k in range(len(mnames))]
# patches2 = [mlines.Line2D([], [], color='k', marker=m, linestyle='None',
                          # markersize=8, label=t) for m,t in zip(symbols, hours)]
l1 = axes[N-1].legend(handles=patches, ncol = 3, loc = (1.05,0), title = 'Metabolite')
# plt.tight_layout()

# %%
dfc = dft[cols_for_corr+['log10(Leakage [mmol/gDW/h])']]
# P = [organic]/[aqueous])

# %%
rho = df.corr()
pval = df.corr(method=lambda x, y: st.pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x<=t]))
rho.round(2).astype(str) + p

# %% [markdown]
# # Get transporter info

# %%
df_trans = pd.read_csv('e_coli_transporters.csv', index_col=0)

# %%
df_trans.loc[df_trans.Membrane == 'inner',:]
dft = df.loc[df.Time.isin([5.5, 6.5, 7.5, 8.5, 9.5, 10.5]), cols_for_corr+['Metabolite name', 'log10(leakage [mmol/gDW/h])', 'Metabolite id']]
mIDs = dft['Metabolite id'].unique()

# %%
idx = df_trans['iML1515 metabolite ID'].isin(mIDs)*(df_trans.Membrane == 'inner')
dfT = df_trans.loc[idx,:]

# %%
# dfTT = dfT.loc[dfT.Direction.str.contains('Export'),:]

# %%
dfT['Transport type'].unique()
other_lst = ['4abut antiporter', 'agm antiporter',
       'orn antiporter', 'pi antiporter', 'succ antiporter', 'ATP-binding cassette transporter']
dfT.loc[dfT['Transport type'].isin(other_lst), 'Transport type'] = 'Other'

# %%
T_dict = {}
for mname in mIDs:
    tmp = dfT.loc[dfT['iML1515 metabolite ID'] == mname]
    if len(tmp)<3 and len(tmp)>0:
        T_dict[mname] = ", ".join(tmp['Transport type'].sort_values().unique())
    elif len(tmp)==0:
        T_dict[mname] = 'None'
    else:
        T_dict[mname] = 'Three or more different transporters'

# %%
dft['Transporter'] = dft['Metabolite id'].map(T_dict)
dft.sort_values(by='Transporter', inplace = True)

# %%
sns.boxplot(data = dft, x = 'log10(leakage [mmol/gDW/h])', y = 'Transporter')
# plt.legend(loc=(1.05,0))
plt.title('Estimated leakage rates grouped by annotated transporters')

# %% [markdown]
# # Plot a cumulative distribution of shadow prices

# %%
model = cobra.io.read_sbml_model('../../models/e_coli/momentiJO1366.xml')
model.solver = 'gurobi'
# model.reactions.DHAPT.knock_out()
# model.reactions.THRA.knock_out()
# model.reactions.THRA2.knock_out()
# model.reactions.F6PA_TG_forward.knock_out()
# Speculations
# model.reactions.PFL.knock_out()
#I'm more and more conviced that PFL is not active in aerobic conditions
# https://doi.org/10.1016/j.jbc.2021.101423
model.reactions.EX_glc__D_e.lower_bound = -6
solution = cobra.flux_analysis.pfba(model)
print(model.summary(solution))

# %%
sp = leakage.estimate_shadow_prices(model, delta=0.1)
# solution = model.optimize()
# sp = solution.shadow_prices

# %%
Ssp = pd.Series(sp)

# %%
solution = cobra.flux_analysis.pfba(model)
# solution = model.optimize()
turnover_dict = {}
for m in model.metabolites:
    if m.compartment == 'c':
        turnover_dict[m.id] = m.summary(solution).producing_flux['flux'].sum()

# %%
sp_list = []
met_ids = []
for m in model.metabolites:
    # Remove non-organic compounds
    if m.id in ['hco3_c', 'co2_c']:
        continue
    if m.compartment == 'c':
        if 'C' in m.elements.keys():
            if m.formula_weight and (m.formula_weight < 500):
                if turnover_dict[m.id] >0:
                    if 'C' in m.elements.keys():
                        if sp[m.id] < 0:
                            met_ids.append(m.id)
                            sp_list.append(sp[m.id])

# %%
selected_sp = pd.Series(sp_list, index = met_ids)
selected_sp.dropna(inplace = True)

# %%
selected_sp.sort_values(inplace = True, ascending=False)

# %%
model.metabolites.fdp_c

# %%
max_leak = df.loc[:, ['Metabolite name','Metabolite id', 'log10(leakage [mmol/gDW/h])']].groupby('Metabolite name').max()
smax = max_leak['log10(leakage [mmol/gDW/h])'].max()
smin = max_leak['log10(leakage [mmol/gDW/h])'].min()

# %%
max_leak.set_index('Metabolite id', inplace = True)

# %%
selected_sp.index = [m[:-2] for m in selected_sp.index]

# %%
# fig, [ax1, ax2] = plt.subplots(1,2, figsize = (16,6))
fig, ax = plt.subplots(1, figsize = (16,4))

norm = plt.Normalize(vmin=smin, vmax=smax)
#norm = matplotlib.colors.BoundaryNorm([0,1,2,3], cmap.N, extend='neither')
cmap = plt.cm.viridis
sm = matplotlib.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

consumed_sp = []
produced_sp = []
both_sp = []
max_leak_dict = {}
for i, row in max_leak.iterrows():
    leak = row['log10(leakage [mmol/gDW/h])']
    met_ids = i.split(', ')
    for m_id in met_ids:
        try:
            met = selected_sp[m_id]
        except KeyError:
            print(m_id)
        else:
            max_leak_dict[m_id]=leak


for i, (m_id, sp_i) in enumerate(selected_sp.items()):
    try:
        leak_i = max_leak_dict[m_id]
    except KeyError:
        ax.plot([i+1,i+1], [0, -sp_i], c = 'k', alpha = 0.5, lw = 3) 
    else:
        ax.plot([i+1, i+1], [0, -sp_i], lw = 3, c = sm.to_rgba(leak_i))# colouring is wrong , lw = 2)#, cmap = cmap, norm = norm)


        
    
#     # # Make a seperate plot for the 10% least expensive
#     # if i < first_x:
    #     if leak_i > 0:
    #         ax2.scatter(i, sp_abs, s = 50, c = np.log(leak_i), cmap = cmap, norm = norm)
    #     else:
    #         ax2.scatter(i, sp_abs,s=10, c = 'k', alpha = 0.5)
    #     ax2.annotate(m_id[:-2], (i+0.5, sp_abs*0.9))

    
    
#ax.scatter(np.arange(len(selected_sp)), np.abs(selected_sp), s = 10)
ax.set_yscale('log')
#ax1.set_xlim(0,400)
# ax2.set_yscale('log')
# ax2.set_xlim(0, first_x+5)
ax.set_ylabel('-1 * Shadow price [gDW/mmol]', fontdict={'size':14})
# ax2.set_ylabel('-1 * Shadow price')
ax.set_xlabel('Rank', fontdict={'size':14})
# ax2.set_xlabel('Rank')
ax.set_xlim(0, i+2)
ax.tick_params(axis='both', which='major', labelsize=14)
fig.colorbar(sm, ax = ax, label = "Maximum log10-scaled leakage rates")
# plt.savefig('Rank of shadow price ecoli knock outs epsilon 001.png')

# %%
st.ttest_ind(both_sp, consumed_sp, equal_var=False)

# %% [markdown]
# # Predict!

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, ElasticNet, ARDRegression, BayesianRidge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn import tree
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm

# %%
# dft = df.loc[df.Time.isin(np.arange(1.5, 9, 1)), :]
hours = [1.5, 2.5, 3.5,4.5,5.5,7.5,8.5] 
dft = df.loc[df.Time.isin(hours), :]


cols_for_corr = ['Mass',
       'Charge', 'Phosphate', 'Topological Polar Surface Area [Å]',
       # 'Shadow price [gDW/mmol]',
                 'log10(-Shadow price [gDW/mmol])',
       'log10(Turnover [mmol/gDW/h])', 'log P']

columns = cols_for_corr
# columns = ['Shadow price [gDW/mmol]', 'log10(Turnover [mmol/gDW/h])', 'log P']
# columns = ['log10(-Shadow price [gDW/mmol])', 'Mass', 'Charge', 'log P', 'Topological Polar Surface Area [Å]']
# columns = ['log10(-Shadow price [gDW/mmol])']
tmp = dft.loc[~dft['Leakage (mmol/gDW/h)'].isna(),columns+['log10(Leakage [mmol/gDW/h])', 'Metabolite name']]
# tmp['log10(Turnover [mmol/gDW/h])'].fillna(0, inplace = True) #tmp['log10(Turnover)']
tmp.dropna(inplace=True)
y = tmp['log10(Leakage [mmol/gDW/h])']
# X = tmp['Shadow price [gDW/mmol]']

# %%
# data = StandardScaler().fit_transform(tmp[columns])
# X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.1)#, random_state=40)
#6.5

# %%
fig, ax = plt.subplots(1, figsize = (6, 4))
ypreds = []
yvals = []
mnames = tmp['Metabolite name'].unique()
for i, mname in enumerate(mnames):
    idx = tmp['Metabolite name']==mname
    linear_reg = LinearRegression(fit_intercept = True).fit(np.array(tmp.loc[~idx, columns]),y[~idx])
    Xi = np.array(tmp.loc[idx, columns])#reshape(1,-1)
    yi = linear_reg.predict(Xi)
    ypreds += list(yi)
    yvals += list(y[idx])
    ax.scatter(y[idx], yi, color = cmap40(i), label = mname,s = 70, alpha = 0.8)
# plt.scatter(ypreds, y)
l = np.linspace(-6,1)
plt.plot(l,l,c='k',ls = '--', alpha = 0.5)
plt.legend(ncol = 2, loc = (1.05, 0))
ypreds = np.array(ypreds)
yvals = np.array(yvals)

SSres = np.sum((ypreds-yvals)**2)
SStot = np.sum((yvals-np.mean(yvals))**2)
R2 = 1-(SSres/SStot)
print(R2)

X = sm.add_constant(np.array(tmp[columns]))
model = sm.OLS(y, X)
res = model.fit()

plt.xlabel('Estimated leakage', fontdict={'size': 16})
plt.ylabel('Predicted leakage', fontdict={'size': 16})
plt.title('Leave-one-out predictions')
plt.text(-3, -6, "$R^2$ LOO: {0:.2f}, $R^2$: {1:.2f}".format(R2, res.rsquared), fontdict={'size': 14})
# Out:
# 0.29782651494136847
# Text(-3, -6, '$R^2$ LOO: 0.30, $R^2$: 0.58')

# %%
all_sets = [list(x) for x in utils.powerset(cols_for_corr) if len(x)]

# %%
R2_arr = np.zeros(len(all_sets))
dft = df.loc[df.Time.isin(np.arange(1.5, 9, 1)), :]
R2_full = []
for j, cols in enumerate(all_sets):
    tmp = dft.loc[~dft['Leakage (mmol/gDW/h)'].isna(),cols+['log10(Leakage [mmol/gDW/h])', 'Metabolite name']]
    # tmp['log10(Turnover [mmol/gDW/h])'].fillna(0, inplace = True) #tmp['log10(Turnover)']
    tmp.replace([np.inf, -np.inf], np.nan, inplace=True)
    tmp.dropna(inplace=True)
    tmp.reset_index(inplace = True)
    y = tmp['log10(Leakage [mmol/gDW/h])']
    ypreds = []
    yvals = []
    mnames = tmp['Metabolite name'].unique()
    for i, mname in enumerate(mnames):
        idx = tmp['Metabolite name']==mname
        linear_reg = LinearRegression(fit_intercept = True).fit(np.array(tmp.loc[~idx, cols]),y[~idx])
        Xi = np.array(tmp.loc[idx, cols])#reshape(1,-1)
        yi = linear_reg.predict(Xi)
        ypreds += list(yi)
        yvals += list(y[idx])
        
    X = sm.add_constant(np.array(tmp[cols]))
    model = sm.OLS(y, X)
    res = model.fit()
    R2_full.append(res.rsquared)
       
    ypreds = np.array(ypreds)
    yvals = np.array(yvals)

    SSres = np.sum((ypreds-yvals)**2)
    SStot = np.sum((yvals-np.mean(yvals))**2)
    R2 = 1-(SSres/SStot)
    R2_arr[j] = R2

# %%
labels = []
lengths = []
for cols in all_sets:
    cols = list(cols)
    lengths.append(len(cols))
    if len(cols) > 1:
        n = ", ".join(cols)
        labels.append(n)
    else:
        labels.append(cols[0])
    
R2df = pd.DataFrame([labels, R2_arr, R2_full, lengths]).T
R2df.columns = ['Label', 'R2 LOO', 'R2', 'N params']

# %%
R2df.sort_values('R2 LOO', ascending=False, inplace=True)
R2df.head(12)
# Out:
#                                                  Label    R2 LOO        R2  \
# 7                                         Mass, Charge  0.392375   0.54633
# 31          Mass, Charge, log10(Turnover [mmol/gDW/h])  0.392163  0.560115
# 30       Mass, Charge, log10(-Shadow price [gDW/mmol])  0.380108   0.54711
# 72   Mass, Charge, log10(Turnover [mmol/gDW/h]), log P    0.3729  0.574484
# 71   Mass, Charge, log10(-Shadow price [gDW/mmol]),...  0.372015  0.562874
# 32                                 Mass, Charge, log P  0.370139  0.558249
# 70   Mass, Charge, log10(-Shadow price [gDW/mmol]),...   0.36982  0.560225
# 107  Mass, Charge, log10(-Shadow price [gDW/mmol]),...   0.36005  0.576377
# 68   Mass, Charge, Topological Polar Surface Area [...  0.355401  0.561948
# 29    Mass, Charge, Topological Polar Surface Area [Å]  0.350714  0.546801
# 65   Mass, Charge, Phosphate, log10(Turnover [mmol/...  0.348274  0.561211
# 28                             Mass, Charge, Phosphate  0.347938  0.547055
#
#     N params
# 7          2
# 31         3
# 30         3
# 72         4
# 71         4
# 32         3
# 70         4
# 107        5
# 68         4
# 29         3
# 65         4
# 28         3

# %%
for x in R2df.head(10)['Label']:
    print(x)
# Out:
# Mass, Charge
# Mass, Charge, log10(Turnover [mmol/gDW/h])
# Mass, Charge, log10(-Shadow price [gDW/mmol])
# Mass, Charge, log10(Turnover [mmol/gDW/h]), log P
# Mass, Charge, log10(-Shadow price [gDW/mmol]), log P
# Mass, Charge, log P
# Mass, Charge, log10(-Shadow price [gDW/mmol]), log10(Turnover [mmol/gDW/h])
# Mass, Charge, log10(-Shadow price [gDW/mmol]), log10(Turnover [mmol/gDW/h]), log P
# Mass, Charge, Topological Polar Surface Area [Å], log10(Turnover [mmol/gDW/h])
# Mass, Charge, Topological Polar Surface Area [Å]

# %%
# Mass, Charge, Topological Polar Surface Area [Å], log10(-Shadow price [gDW/mmol]), log P

# %%
plt.bar(np.arange(len(R2_arr)), R2df['R2 LOO'])
plt.xlabel('Rank')
plt.ylabel('$R^2$ for leave-one-out CV')
# Out:
# Text(0, 0.5, '$R^2$ for leave-one-out CV')

# %%
ypreds = []
for i, idx in enumerate(tmp.index):
    linear_reg = LinearRegression(fit_intercept = True).fit(np.array(tmp[columns].drop(idx)),y.drop(idx))
    Xi = np.array(tmp.loc[idx, columns]).reshape(1,-1)
    ypreds.append(linear_reg.predict(Xi)[0])

plt.scatter(ypreds, y)
l = np.linspace(-5,-2)
plt.plot(l,l,c='k',ls = '--', alpha = 0.5)

SSres = np.sum((ypreds-y)**2)
SStot = np.sum((y-np.mean(y))**2)
R2 = 1-(SSres/SStot)
print(R2)
# Out:
# 0.5368298385734018

# %%
Xi

# %%
X = sm.add_constant(tmp[columns])
model = sm.OLS(y, X)
res = model.fit()
print(res.summary())

# %%
plt.scatter(res.predict(), y)
ypreds = res.predict()
SSres = np.sum((ypreds-y)**2)
SStot = np.sum((y-np.mean(y))**2)
R2 = 1-(SSres/SStot)
print(R2)

# %%
X = sm.add_constant(StandardScaler().fit_transform(tmp[columns]))
model = sm.OLS(y, X)
res = model.fit()
print(res.summary())

# %%
np.log10

# %%
N = 100
coefficients = np.zeros((2,N))*np.nan

R2_arr_oo = np.zeros(N)
R2_arr = np.zeros(N)
R2_arr_test = np.zeros(N)
# data = StandardScaler().fit_transform(tmp[columns])
data = sm.add_constant(tmp[columns])

for i in range(N):
    X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.05)#, random_state=40)
    linear_reg = LinearRegression(fit_intercept = True).fit(X_train, y_train)
    coefficients[:, i] = linear_reg.coef_
    R2_arr[i] = linear_reg.score(X_train, y_train)
    R2_arr_oo[i] = linear_reg.score(X_test, y_test)

plt.barh(columns, coefficients.mean(axis=1), xerr = coefficients.std(axis=1))
plt.show()

# %%
X_test.shape

# %%
fig, ax = plt.subplots(1)
ax.bar(["R2 within sample", "R2 out of sample"], [R2_arr.mean(), R2_arr_oo.mean()], yerr = [R2_arr.std(), R2_arr_oo.std()])
ax.set_ylim(-1, 1)
plt.show()

# %%
dft = df.loc[df.Time==6.5, :]
tmp = dft.loc[~dft.isna().any(axis =1),:]
y = tmp['log10(leakage [mmol/gDW/h])']
X = tmp['Shadow price [gDW/mmol]']

# %%
X = np.array(X).reshape(-1,1)
# x = np.array(y).reshape(-1,1)

# %%
lr = linear_model.LinearRegression(fit_intercept = True)
ransac = linear_model.RANSACRegressor()

# %%
lr.fit(X,y)
ransac.fit(X,y)

# %%
line_X = np.linspace(X.min(), X.max(), 10)[:, np.newaxis]

# %%
y1 = lr.predict(line_X)
y2 = ransac.predict(line_X)

# %%
plt.scatter(X,y)
plt.plot(line_X, y1, label = 'Linear regression')
plt.plot(line_X, y2, label = 'Ransac')
plt.legend()

# %%
y1
