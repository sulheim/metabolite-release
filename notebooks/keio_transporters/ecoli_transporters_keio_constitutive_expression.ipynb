# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Adding protein abundance data
# This paper has absolute protein abundance data for different E. coli strains in different conditions. The goal of this notebook is to extract protein abundance data and Ribo-Seq data for E. coli grown in glucose M9 (or similar) to get an idea of which transporters that are constitutively expressed

# %%
# Data
folder = Path('/Users/ssulheim/Library/CloudStorage/OneDrive-UniversitédeLausanne/UNIL/leakage/data/mori_msb_2021_proteome_ecoli')
fn2 = folder / 'msb20209536-sup-0003-datasetev2.xlsx' # Sample info
fn3 = folder / 'msb20209536-sup-0004-datasetev3.xlsx' # Sample info
fn6 = folder / 'msb20209536-sup-0007-datasetev6.xlsx' # Data for "calibration samples on E. coli in MOPS medium"
fn8 = folder / 'msb20209536-sup-0009-datasetev8.xlsx' # Data for samples listed in fn2
fn9 = folder / 'msb20209536-sup-0010-datasetev9.xlsx' # Data for samples listed in fn3



selected_transporters = Path('/Users/ssulheim/Library/CloudStorage/OneDrive-UniversitédeLausanne/UNIL/leakage/experimental work/KEIO_transporter_knockouts/selected_transporters.xlsx')
df_sel = pd.read_excel(selected_transporters, skiprows=4, usecols='A:Q')
# df_sel = pd.read_excel(selected_transporters, sheet_name='Table EV1A', skiprows=3, usecols='A:H').iloc[1:]

# %%
df6 = pd.read_excel(fn6, sheet_name='EV6-CalibrationSamplesProteins', header = [0,1])
df8 = pd.read_excel(fn8, sheet_name='EV8-AbsoluteMassFractions-1')
df9 = pd.read_excel(fn9, sheet_name='EV9-AbsoluteMassFractions-2')

# %%
df6.rename(columns={"Unnamed: 0_level_1":'',	"Unnamed: 1_level_1":'',	"Unnamed: 2_level_1":'',	"Unnamed: 3_level_1":'', "Unnamed: 4_level_1":''}, level = 1, inplace=True)
df6.columns = ['_'.join(col) if len(col[1]) else col[0] for col in df6.columns]

# %%
xtop1_cols = [x for x in df6.columns if 'xTop' in x]

# %%
# idx = np.where(df6['Gene locus'] == gene_name)[0][0]

# %%
df6_drop = ['TopPep1_A1-1', 'TopPep1_A1-2', 'TopPep1_A1-3', 'TopPep1_C1',
       'TopPep1_F1-1', 'TopPep1_F1-2', 'TopPep1_F1-3', 'TopPep3_A1-1',
       'TopPep3_A1-2', 'TopPep3_A1-3', 'TopPep3_C1', 'TopPep3_F1-1',
       'TopPep3_F1-2', 'TopPep3_F1-3', 'iBAQ_A1-1', 'iBAQ_A1-2', 'iBAQ_A1-3',
       'iBAQ_C1', 'iBAQ_F1-1', 'iBAQ_F1-2', 'iBAQ_F1-3']
df6.drop(columns=df6_drop, inplace=True)

# %%
gene_locus_to_weight = df6.set_index('Gene locus')['Molecular weight (kDa)'].to_dict()

# %%
# Convert from mass fractions to number fractions
total_mass = {x: np.sum(df6[x]/df6['Molecular weight (kDa)']) for x in xtop1_cols}
for key, value in total_mass.items():
    df6[key] = (df6[key]/df6['Molecular weight (kDa)'])/value

# %%
selected_cols_df8 = ["Lib-24", "Lib-25", "Lib-26", "Lib-27", "Lib-28", "Lib-29", "Lib-30", "Lib-06"] # "Lib-00-A1", "Lib-00-A2", "Lib-00-A3", "Lib-00-B1", "Lib-00-B2", "Lib-00-B3"

selected_cols_df9 = ["A1-1", "A1-2", "A1-3", "C1", "F1-1", "F1-2", "F1-3", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "D6", "D7", "D8", "F4", "F5", "F6", "F7", "F8"]

# %%
#Convert df8 to number fractions
df8['Molecular weight (kDa)'] = df8['Gene locus'].map(gene_locus_to_weight)
df9['Molecular weight (kDa)'] = df9['Gene locus'].map(gene_locus_to_weight)

total_mass_8 = {x: np.sum(df8[x]/df8['Molecular weight (kDa)']) for x in selected_cols_df8}
total_mass_9 = {x: np.sum(df9[x]/df9['Molecular weight (kDa)']) for x in selected_cols_df9}
for key, value in total_mass_8.items():
    df8[key] = (df8[key]/df8['Molecular weight (kDa)'])/value
    
for key, value in total_mass_9.items():
    df9[key] = (df9[key]/df9['Molecular weight (kDa)'])/value

# %%
df8_all =  ['Lib-01', 'Lib-02', 'Lib-03','Lib-04', 'Lib-05', 'Lib-06', 'Lib-07', 'Lib-08', 'Lib-09', 'Lib-10',
       'Lib-11', 'Lib-12', 'Lib-13', 'Lib-14', 'Lib-15', 'Lib-16', 'Lib-17',
       'Lib-18', 'Lib-19', 'Lib-20', 'Lib-21', 'Lib-22', 'Lib-23', 'Lib-24',
       'Lib-25', 'Lib-26', 'Lib-27', 'Lib-28', 'Lib-29', 'Lib-30']

# %%
df9_all = ['A1-1', 'A1-2', 'A1-3', 'C1',
       'F1-1', 'F1-2', 'F1-3', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'D6',
       'D7', 'D8', 'F4', 'F5', 'F6', 'F7', 'F8', 'D1', 'D2', 'D3', 'D4', 'D5',
        'F2', 'F3', 'A2', 'E1', 'E2', 'E3', 'E4', 'H1', 'H5']

# %%
# values8 = df8.loc[idx8, selected_cols_df8]

# %%
mean_protein_number_fraction = []
std_protein_number_fraction = []
detected_in_all_c_limit = []
detected_in_all = []
ribo_seq = []
for i, row in df_sel.iterrows():
    try:
        idx6 = np.where(df6['Gene locus']==row['Blattner ID'])[0][0]
        idx8 = np.where(df8['Gene locus']==row['Blattner ID'])[0][0]
        idx9 = np.where(df8['Gene locus']==row['Blattner ID'])[0][0]
    except IndexError:
        mean_protein_number_fraction.append(None)
        std_protein_number_fraction.append(None)
        detected_in_all_c_limit.append(None)
        detected_in_all.append(None)
        ribo_seq.append(None)
    else:
        values6 = df6.loc[idx6, xtop1_cols].values
        values8 = df8.loc[idx8, selected_cols_df8].values
        values9 = df9.loc[idx9, selected_cols_df9].values
        values = np.concatenate([values6, values8, values9])
        mean_protein_number_fraction.append(np.mean(values))
        std_protein_number_fraction.append(np.std(values))
        detected_in_all_c_limit.append(np.sum(values>0)/len(values))
        all_values = np.concatenate([df6.loc[idx6, xtop1_cols].values, 
                                     df8.loc[idx8, df8_all].values,
                                     df9.loc[idx9, df9_all].values])
        detected_in_all.append(np.sum(all_values>0)/len(all_values))
            
        ribo_seq.append(df6.loc[idx6, 'Ribosome profiling (Li et al., 2014)'])

# %%
df_sel['Mean protein number fraction'] = mean_protein_number_fraction
df_sel['Std protein number fraction'] = std_protein_number_fraction
df_sel['Detected in fraction of all conditions'] = detected_in_all
df_sel['Detected in fraction of all C-limit conditions'] = detected_in_all_c_limit
df_sel['Ribosome profiling (Li et al., 2014)'] = ribo_seq

# %%
df_sel.tail()
# Out:
#      Sample Number   JW ID Blattner ID Gene Name  \
# 103          104.0  JW4038       b4077      gltP
# 104          105.0  JW0009       b0010      satP
# 105          106.0  JW1718       b1729      tcyP
# 106          107.0  JW2910       b2943      galP
# 107            NaN  JW1652       b1660      punC
#
#                                  Annotation  \
# 103    glutamate/aspartate:proton symporter
# 104          acetate/succinate:H+ symporter
# 105  cystine/sulfocysteine:cation symporter
# 106                 D-galactose transporter
# 107                   predicted transporter
#
#      Growth rate in glucose + AA medium  Selection score (0-3)  \
# 103                                0.86                    3.0
# 104                                0.64                    3.0
# 105                                0.83                    1.0
# 106                                0.84                    2.0
# 107                                0.76                    3.0
#
#            Location                 Transport  \
# 103  Inner membrane  L-aspartate, L-glutamate
# 104  Inner membrane        Acetate, succinate
# 105  Inner membrane                 L-cystine
# 106  Inner membrane      Galactose, D-glucose
# 107  Inner membrane                   Purines
#
#                                                  Class  ... TCID  \
# 103  dicarboxylate/amino acid:cation symporter (DAA...  ...  NaN
# 104                 Acetate Uptake Transporter (AceTr)  ...  NaN
# 105  dicarboxylate/amino acid:cation symporter (DAA...  ...  NaN
# 106                                                MFS  ...  NaN
# 107                                                MFS  ...  NaN
#
#                                            biocyc link  \
# 103                                                NaN
# 104     https://biocyc.org/gene?orgid=ECOLI&id=EG11512
# 105       https://biocyc.org/gene?orgid=ECOLI&id=G6934
# 106     https://biocyc.org/gene?orgid=ECOLI&id=EG12148
# 107  https://ecocyc.org/gene?orgid=ECOLI&id=YDHC-MO...
#
#                                                Comment  \
# 103  GltP accounts for approximately 60% of the tot...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107  While the punC deletion in general has a negat...
#
#                                          Paper Location in operon  \
# 103                                        NaN                NaN
# 104                                        NaN                NaN
# 105                                        NaN                NaN
# 106                                        NaN                NaN
# 107  https://pubmed.ncbi.nlm.nih.gov/34413462/                NaN
#
#     Mean protein number fraction Std protein number fraction  \
# 103                     0.000000                    0.000000
# 104                     0.000000                    0.000000
# 105                     0.000423                    0.000192
# 106                     0.000000                    0.000000
# 107                     0.000000                    0.000000
#
#      Detected in fraction of all conditions  \
# 103                                     0.0
# 104                                     0.0
# 105                                     1.0
# 106                                     0.0
# 107                                     0.0
#
#      Detected in fraction of all C-limit conditions  \
# 103                                             0.0
# 104                                             0.0
# 105                                             1.0
# 106                                             0.0
# 107                                             0.0
#
#      Ribosome profiling (Li et al., 2014)
# 103                             6813924.0
# 104                              889694.0
# 105                           128468400.0
# 106                            11495660.0
# 107                             2022080.0
#
# [5 rows x 22 columns]

# %%
df_sel['log10(Mean protein number fraction)'] = np.log10(df_sel['Mean protein number fraction'])
df_sel['log10(Ribosome profiling)'] = np.log10(df_sel['Ribosome profiling (Li et al., 2014)'])
# Out:
# /Users/ssulheim/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ssulheim/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_sel.drop(columns=['Location in operon'], inplace=True)
df_sel.replace(-np.inf, np.nan, inplace=True)

# %%
fn_new = '/Users/ssulheim/Library/CloudStorage/OneDrive-UniversitédeLausanne/UNIL/leakage/experimental work/KEIO_transporter_knockouts/selected_transporters_with_exp.xlsx'
# fn_new = '/Users/ssulheim/Library/CloudStorage/OneDrive-UniversitédeLausanne/UNIL/leakage/experimental work/KEIO_transporter_knockouts/keio_KO_with_proteome_data.xlsx'
df_sel.to_excel(fn_new, index=False)

# %%
# df_sel['biocyc link'] = df_sel['biocyc link'].apply(lambda x: f'=HYPERLINK("{x}", "{str(x).split('=')[-1]}")')

# %%
df_sel
# Out:
#     Sample Number   JW ID Blattner ID Gene Name  \
# 0               1  JW0401       b0411       tsx
# 1               2  JW2203       b2215      ompC
# 2               3  JW0912       b0929      ompF
# 3               4  JW1469       b1473      yddG
# 4               5  JW0231       b0241      phoE
# ..            ...     ...         ...       ...
# 91             92  JW0665       b0679      nagE
# 92             93  JW2900       b2933      cmtA
# 93             94  JW0069       b0070      setA
# 94             95  JW3898       b3927      glpF
# 95             96  JW3733       b3754      hsrA
#
#                                            Annotation  \
# 0   nucleoside channel, receptor of phage T6 and c...
# 1                      outer membrane porin protein C
# 2                    outer membrane porin 1a (Ia;b;F)
# 3                        aromatic amino acid exporter
# 4               outer membrane phosphoporin protein E
# ..                                                ...
# 91  fused N-acetyl glucosamine specific PTS enzyme...
# 92  predicted fused mannitol-specific PTS enzymes:...
# 93              broad specificity sugar efflux system
# 94                               glycerol facilitator
# 95  predicted multidrug or homocysteine efflux system
#
#     Growth rate in glucose + AA medium  Selection score (0-3)        Location  \
# 0                                 0.92                    1.0  Outer membrane
# 1                                 0.89                    3.0  Outer membrane
# 2                                 0.77                    2.0  Outer membrane
# 3                                 0.78                    3.0  Inner membrane
# 4                                 0.86                    1.0  Outer membrane
# ..                                 ...                    ...             ...
# 91                                0.80                    1.0  Inner membrane
# 92                                0.86                    0.0  Inner membrane
# 93                                0.82                    2.0  Inner membrane
# 94                                0.94                    4.0  Inner membrane
# 95                                0.97                    2.0  Inner membrane
#
#                                   Transport  \
# 0                                Nucleoside
# 1                                Unspecific
# 2                                Unspecific
# 3                broad range of amino acids
# 4                Phosphor related compounds
# ..                                      ...
# 91                     N-acetyl glucosamine
# 92                                 mannitol
# 93                         Lactose, glucose
# 94  Glycerol, glyceraldehyde, glycine, urea
# 95             Serine, hydroxyglutaric acid
#
#                                    Class  ...  \
# 0                                  Porin  ...
# 1                                  Porin  ...
# 2                                  Porin  ...
# 3                                    DMT  ...
# 4                                  Porin  ...
# ..                                   ...  ...
# 91                                   PTS  ...
# 92                                   PTS  ...
# 93                                   MFS  ...
# 94  major intrinsic protein (MIP) family  ...
# 95                                   MFS  ...
#
#                                                  TCID  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://www.tcdb.org/search/result.php?tc=2.A....
# 4     https://tcdb.org/search/result.php?tc=1.b.1.1.2
# ..                                                ...
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
#
#                                           biocyc link  \
# 0   =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 1   =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 2   =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 3   =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 4   =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# ..                                                ...
# 91  =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 92  =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 93  =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 94  =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
# 95  =HYPERLINK("https://biocyc.org/gene?orgid=ECOL...
#
#                                               Comment  \
# 0                                                 NaN
# 1   OpmC is reciprocally regulated with ompF. Both...
# 2                                                 NaN
# 3   Overexpression of YddG increases accumulation ...
# 4        Less than 600 Dalton (same as OmpC and OmpF)
# ..                                                ...
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94  glpF mutants have impaired growth on low conce...
# 95  Recent paper shows its influence on serine, hy...
#
#                                                 Paper Location in operon  \
# 0   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...                NaN
# 1                              10.1074/jbc.M602112200                NaN
# 2                              10.1074/jbc.M602112200                NaN
# 3   https://academic.oup.com/femsle/article/275/2/...                NaN
# 4                                                 NaN                NaN
# ..                                                ...                ...
# 91                                                NaN                NaN
# 92                                                NaN                NaN
# 93                                                NaN                NaN
# 94                                                NaN                NaN
# 95          https://doi.org/10.3390/membranes14030070                NaN
#
#    Mean protein number fraction Std protein number fraction  \
# 0                      0.000576                    0.000149
# 1                      0.004423                    0.004462
# 2                      0.010954                    0.003789
# 3                      0.000000                    0.000000
# 4                      0.000038                    0.000070
# ..                          ...                         ...
# 91                     0.000093                    0.000047
# 92                     0.000000                    0.000000
# 93                     0.000000                    0.000000
# 94                     0.000007                    0.000038
# 95                     0.000000                    0.000000
#
#     Detected in fraction of all conditions  \
# 0                                 1.000000
# 1                                 1.000000
# 2                                 1.000000
# 3                                 0.000000
# 4                                 0.602740
# ..                                     ...
# 91                                1.000000
# 92                                0.000000
# 93                                0.000000
# 94                                0.164384
# 95                                0.000000
#
#     Detected in fraction of all C-limit conditions  \
# 0                                         1.000000
# 1                                         1.000000
# 2                                         1.000000
# 3                                         0.000000
# 4                                         0.702703
# ..                                             ...
# 91                                        1.000000
# 92                                        0.000000
# 93                                        0.000000
# 94                                        0.081081
# 95                                        0.000000
#
#     Ribosome profiling (Li et al., 2014)
# 0                           1.524697e+08
# 1                           2.483005e+09
# 2                           3.287487e+09
# 3                           3.161188e+06
# 4                           1.807160e+06
# ..                                   ...
# 91                          1.702147e+07
# 92                          0.000000e+00
# 93                          7.455000e+05
# 94                          2.782800e+05
# 95                          5.993200e+05
#
# [96 rows x 22 columns]

# %%
df8[selected_cols_df8]
# Out:
#         Lib-24    Lib-25    Lib-26    Lib-27    Lib-28    Lib-29    Lib-30  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.000075  0.000076  0.000083  0.000066  0.000077  0.000068  0.000057
# ...        ...       ...       ...       ...       ...       ...       ...
# 4337  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4338  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4339  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4340  0.000000  0.000015  0.000004  0.000018  0.000016  0.000017  0.000000
# 4341  0.000605  0.000612  0.000626  0.000593  0.000547  0.000593  0.000601
#
#         Lib-06
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000061
# ...        ...
# 4337  0.000000
# 4338  0.000000
# 4339  0.000000
# 4340  0.000015
# 4341  0.000364
#
# [4342 rows x 8 columns]

# %%
'Ribosome profiling (Li et al., 2014)'
# Out:
# 'Ribosome profiling (Li et al., 2014)'

# %%
df_sel.head(4)
# Out:
#    Sample Number   JW ID Blattner ID Gene Name  \
# 0              1  JW0401       b0411       tsx
# 1              2  JW2203       b2215      ompC
# 2              3  JW0912       b0929      ompF
# 3              4  JW1469       b1473      yddG
#
#                                           Annotation  \
# 0  nucleoside channel, receptor of phage T6 and c...
# 1                     outer membrane porin protein C
# 2                   outer membrane porin 1a (Ia;b;F)
# 3                       aromatic amino acid exporter
#
#    Growth rate in glucose + AA medium  Selection score (0-3)        Location  \
# 0                                 NaN                    NaN  Outer membrane
# 1                                0.89                    NaN  Outer membrane
# 2                                0.77                    NaN  Outer membrane
# 3                                0.78                    NaN  Inner membrane
#
#                     Transport    Class Mechanism/specific type  \
# 0                  Nucleoside  Channel      Passive diffusion?
# 1                  Unspecific    Porin       Passive diffusion
# 2                  Unspecific    Porin       Passive diffusion
# 3  broad range of amino acids      DMT                 Uniport
#
#   Expected direction                                               TCID  \
# 0              Both?                                                NaN
# 1               Both                                                NaN
# 2               Both                                                NaN
# 3             Export  https://www.tcdb.org/search/result.php?tc=2.A....
#
#   biocyc link                                            Comment  \
# 0         NaN                                                NaN
# 1         NaN  OpmC is reciprocally regulated with ompF. Both...
# 2         NaN                                                NaN
# 3         NaN  Overexpression of YddG increases accumulation ...
#
#   Constitutively expressed                                              Paper
# 0                      NaN  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 1                      NaN                             10.1074/jbc.M602112200
# 2                      NaN                             10.1074/jbc.M602112200
# 3                      NaN  https://academic.oup.com/femsle/article/275/2/...

# %%
# Out:
# 1.0

# %%
protein_weigth = df6.loc[idx, 'Molecular weight (kDa)']
np.mean(df6.loc[idx, xtop1_cols].values)/protein_weigth
# Out:
# 1.817482798713675e-05

# %%
gene_name = 'b0411'
df6.where(df6['Gene locus']==gene_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 gene_name = 'b0411'
# ----> 2 df6.where(df6['Gene locus']==gene_name)
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/generic.py:10978, in NDFrame.where(self, cond, other, inplace, axis, level)
#   10971             warnings.warn(
#   10972                 _chained_assignment_warning_method_msg,
#   10973                 FutureWarning,
#   10974                 stacklevel=2,
#   10975             )
#   10977 other = common.apply_if_callable(other, self)
# > 10978 return self._where(cond, other, inplace, axis, level)
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/generic.py:10638, in NDFrame._where(self, cond, other, inplace, axis, level, warn)
#   10633         cond = cond._constructor_expanddim(
#   10634             {i: cond for i in range(len(self.columns))},
#   10635             copy=False,
#   10636         )
#   10637         cond.columns = self.columns
# > 10638     cond = cond.align(self, join="right", copy=False)[0]
#   10639 else:
#   10640     if not hasattr(cond, "shape"):
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/generic.py:10428, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10426     axis = self._get_axis_number(axis)
#   10427 if isinstance(other, ABCDataFrame):
# > 10428     left, _right, join_index = self._align_frame(
#   10429         other,
#   10430         join=join,
#   10431         axis=axis,
#   10432         level=level,
#   10433         copy=copy,
#   10434         fill_value=fill_value,
#   10435         method=method,
#   10436         limit=limit,
#   10437         fill_axis=fill_axis,
#   10438     )
#   10440 elif isinstance(other, ABCSeries):
#   10441     left, _right, join_index = self._align_series(
#   10442         other,
#   10443         join=join,
#    (...)
#   10450         fill_axis=fill_axis,
#   10451     )
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/generic.py:10503, in NDFrame._align_frame(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10494     join_index, ilidx, iridx = self.index.join(
#   10495         other.index, how=join, level=level, return_indexers=True
#   10496     )
#   10498 if (
#   10499     (axis is None or axis == 1)
#   10500     and not is_series
#   10501     and not self.columns.equals(other.columns)
#   10502 ):
# > 10503     join_columns, clidx, cridx = self.columns.join(
#   10504         other.columns, how=join, level=level, return_indexers=True
#   10505     )
#   10507 if is_series:
#   10508     reindexers = {0: [join_index, ilidx]}
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/indexes/base.py:279, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     269 @functools.wraps(meth)
#     270 def join(
#     271     self,
#    (...)
#     277     sort: bool = False,
#     278 ):
# --> 279     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     280     if not return_indexers:
#     281         return join_index
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/indexes/base.py:4612, in Index.join(self, other, how, level, return_indexers, sort)
#    4610         pass
#    4611     else:
# -> 4612         return self._join_multi(other, how=how)
#    4614 # join on the level
#    4615 if level is not None and (self._is_multi or other._is_multi):
#
# File ~/anaconda3/envs/pandas2/lib/python3.12/site-packages/pandas/core/indexes/base.py:4735, in Index._join_multi(self, other, how)
#    4733 # need at least 1 in common
#    4734 if not overlap:
# -> 4735     raise ValueError("cannot join with no overlapping index names")
#    4737 if isinstance(self, MultiIndex) and isinstance(other, MultiIndex):
#    4738     # Drop the non-matching levels from left and right respectively
#    4739     ldrop_names = sorted(self_names - overlap, key=self_names_order)
#
# ValueError: cannot join with no overlapping index names

# %%
df6
# Out:
#      Gene name Gene locus Protein ID  Molecular weight (kDa)  \
# 0         aaeA      b3241     P46482                  40.265
# 1         aaeB      b3240     P46481                  85.277
# 2         aaeR      b3243     P67662                  40.020
# 3         aaeX      b3242     P46478                   9.025
# 4          aas      b2836     P31119                  93.530
# ...        ...        ...        ...                     ...
# 4337      zraR      b4004     P14375                  56.259
# 4338      zraS      b4003     P14377                  59.325
# 4339      zupT      b3040     P0A8H3                  31.061
# 4340       zur      b4046     P0AC51                  22.292
# 4341       zwf      b1852     P0AC53                  64.461
#
#       Ribosome profiling (Li et al., 2014)  xTop_A1-1  xTop_A1-2  xTop_A1-3  \
# 0                                 201325.0   0.000000   0.000000   0.000000
# 1                                 170554.0   0.000000   0.000000   0.000000
# 2                                3161580.0   0.000000   0.000000   0.000000
# 3                                  45125.0   0.000000   0.000000   0.000000
# 4                                7482400.0   0.000016   0.000017   0.000017
# ...                                    ...        ...        ...        ...
# 4337                             1687770.0   0.000000   0.000000   0.000000
# 4338                              237300.0   0.000000   0.000000   0.000000
# 4339                             6740237.0   0.000000   0.000000   0.000000
# 4340                             3722764.0   0.000061   0.000000   0.000059
# 4341                           124280800.0   0.000234   0.000233   0.000238
#
#        xTop_C1  xTop_F1-1  xTop_F1-2  xTop_F1-3
# 0     0.000000   0.000000   0.000000   0.000000
# 1     0.000000   0.000000   0.000000   0.000000
# 2     0.000000   0.000000   0.000000   0.000000
# 3     0.000000   0.000000   0.000000   0.000000
# 4     0.000017   0.000017   0.000016   0.000017
# ...        ...        ...        ...        ...
# 4337  0.000000   0.000000   0.000000   0.000000
# 4338  0.000000   0.000000   0.000000   0.000000
# 4339  0.000000   0.000000   0.000000   0.000000
# 4340  0.000061   0.000060   0.000071   0.000054
# 4341  0.000253   0.000246   0.000244   0.000241
#
# [4342 rows x 12 columns]
