# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
selected_transporters = Path('/Users/ssulheim/Library/CloudStorage/OneDrive-UniversitédeLausanne/UNIL/leakage/experimental work/KEIO_transporter_knockouts/selected_transporters_final.xlsx')
df = pd.read_excel(selected_transporters, usecols='A:Z', nrows=108)

# %%
df.tail()
# Out:
#      Sample Number   JW ID Blattner ID Gene Name  \
# 103            104  JW4038       b4077      gltP
# 104            105  JW0009       b0010      satP
# 105            106  JW1718       b1729      tcyP
# 106            107  JW2910       b2943      galP
# 107            108  JW1652       b1660      punC
#
#                                  Annotation  \
# 103    glutamate/aspartate:proton symporter
# 104          acetate/succinate:H+ symporter
# 105  cystine/sulfocysteine:cation symporter
# 106                 D-galactose transporter
# 107                   predicted transporter
#
#      Growth rate in glucose + AA medium  Selection score (0-3)  \
# 103                                0.86                    3.0
# 104                                0.64                    3.0
# 105                                0.83                    1.0
# 106                                0.84                    2.0
# 107                                0.76                    3.0
#
#      Selected for pilot  Selected  log10(Mean protein number fraction)  ...  \
# 103                 1.0       1.0                                  NaN  ...
# 104                 NaN       1.0                                  NaN  ...
# 105                 NaN       NaN                            -3.373512  ...
# 106                 NaN       1.0                                  NaN  ...
# 107                 NaN       1.0                                  NaN  ...
#
#      Expected direction TCID  \
# 103              Import  NaN
# 104                Both  NaN
# 105              Import  NaN
# 106              Import  NaN
# 107              Import  NaN
#
#                                            biocyc link  \
# 103                                                NaN
# 104     https://biocyc.org/gene?orgid=ECOLI&id=EG11512
# 105       https://biocyc.org/gene?orgid=ECOLI&id=G6934
# 106     https://biocyc.org/gene?orgid=ECOLI&id=EG12148
# 107  https://ecocyc.org/gene?orgid=ECOLI&id=YDHC-MO...
#
#                                                Comment  \
# 103  GltP accounts for approximately 60% of the tot...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107  While the punC deletion in general has a negat...
#
#                                          Paper Mean protein number fraction  \
# 103                                        NaN                     0.000000
# 104                                        NaN                     0.000000
# 105                                        NaN                     0.000423
# 106                                        NaN                     0.000000
# 107  https://pubmed.ncbi.nlm.nih.gov/34413462/                     0.000000
#
#     Std protein number fraction Detected in fraction of all conditions  \
# 103                    0.000000                                    0.0
# 104                    0.000000                                    0.0
# 105                    0.000192                                    1.0
# 106                    0.000000                                    0.0
# 107                    0.000000                                    0.0
#
#     Detected in fraction of all C-limit conditions  \
# 103                                            0.0
# 104                                            0.0
# 105                                            1.0
# 106                                            0.0
# 107                                            0.0
#
#     Ribosome profiling (Li et al., 2014)
# 103                              6813924
# 104                               889694
# 105                            128468400
# 106                             11495660
# 107                              2022080
#
# [5 rows x 26 columns]

# %%
values = df.loc[df.Selected==1, 'Location'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='Location'>

# %%
df.columns
# Out:
# Index(['Sample Number', 'JW ID', 'Blattner ID', 'Gene Name', 'Annotation',
#        'Growth rate in glucose + AA medium', 'Selection score (0-3)',
#        'Selected for pilot', 'Selected', 'log10(Mean protein number fraction)',
#        'log10(Ribosome profiling)', 'Location', 'Transported metabolites',
#        'Metabolite class', 'Class', 'Mechanism/specific type',
#        'Expected direction', 'TCID', 'biocyc link', 'Comment', 'Paper',
#        'Mean protein number fraction', 'Std protein number fraction',
#        'Detected in fraction of all conditions',
#        'Detected in fraction of all C-limit conditions',
#        'Ribosome profiling (Li et al., 2014)'],
#       dtype='object')

# %%
values = df.loc[df.Selected==1, 'Metabolite class'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='Metabolite class'>

# %%
values = df.loc[df.Selected==1, 'Class'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='Class'>

# %%
values = df.loc[df.Selected==1, 'Mechanism/specific type'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='Mechanism/specific type'>

# %%
df.loc[df.Selected==1, 'Metabolite class'].value_counts()
# Out:
# Metabolite class
# Amino acid              17
# Unspecific               5
# Sugar                    4
# Organic acid             4
# Other                    3
# Peptide                  2
# Drug                     2
# Nucleoside               2
# Nucleobase               2
# Phosphorylated sugar     2
# Unknown                  1
# Name: count, dtype: int64
