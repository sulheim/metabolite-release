# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
selected_transporters = Path('/Users/ssulheim/Library/CloudStorage/OneDrive-UniversitédeLausanne/UNIL/leakage/experimental work/KEIO_transporter_knockouts/selection_of_transport_KO_strains/selected_transporters_final.xlsx')
df = pd.read_excel(selected_transporters, usecols='A:AB', nrows=108)

# %%
df.tail()
# Out:
#      Sample Number    JW ID  Plate Column1 Blattner ID Gene Name  \
# 103             69   JW5619    NaN     NaN       b3709      tnaB
# 104             84   JW3991    NaN     NaN       b4031      xylE
# 105             93   JW2900    NaN     NaN       b2933      cmtA
# 106             97  Unknown    NaN     NaN       b0612      citT
# 107            103   JW4084    NaN     NaN       b4123      dcuB
#
#                                             Annotation  \
# 103             tryptophan transporter of low affinity
# 104                               D-xylose transporter
# 105  predicted fused mannitol-specific PTS enzymes:...
# 106                       citrate:succinate antiporter
# 107  C4-dicarboxylate transporter, anaerobic; DcuS ...
#
#      Growth rate in glucose + AA medium  Selection score (0-3)  \
# 103                                0.76                    3.0
# 104                                0.77                    1.0
# 105                                0.86                    0.0
# 106                                0.84                    1.0
# 107                                0.77                    1.0
#
#      Selected for pilot  ...  Expected direction  TCID  \
# 103                 NaN  ...              Import   NaN
# 104                 NaN  ...              Import   NaN
# 105                 NaN  ...              Import   NaN
# 106                 NaN  ...                Both   NaN
# 107                 NaN  ...                Both   NaN
#
#                                         biocyc link  \
# 103  https://biocyc.org/gene?orgid=ECOLI&id=EG11006
# 104  https://biocyc.org/gene?orgid=ECOLI&id=EG11076
# 105  https://biocyc.org/gene?orgid=ECOLI&id=EG11792
# 106    https://biocyc.org/gene?orgid=ECOLI&id=G6338
# 107  https://biocyc.org/gene?orgid=ECOLI&id=EG10006
#
#                                                Comment Paper  \
# 103                        Under catabolite repression   NaN
# 104                                                NaN   NaN
# 105                                                NaN   NaN
# 106  CitT is a putative citrate/succinate antiporte...   NaN
# 107                                                NaN   NaN
#
#     Mean protein number fraction Std protein number fraction  \
# 103                     0.000000                    0.000000
# 104                     0.000006                    0.000039
# 105                     0.000000                    0.000000
# 106                     0.000000                    0.000000
# 107                     0.000000                    0.000000
#
#     Detected in fraction of all conditions  \
# 103                               0.054795
# 104                               0.041096
# 105                               0.000000
# 106                               0.000000
# 107                               0.095890
#
#     Detected in fraction of all C-limit conditions  \
# 103                                       0.000000
# 104                                       0.027027
# 105                                       0.000000
# 106                                       0.000000
# 107                                       0.000000
#
#     Ribosome profiling (Li et al., 2014)
# 103                                    0
# 104                                    0
# 105                                    0
# 106                                    0
# 107                                    0
#
# [5 rows x 28 columns]

# %%
values = df.loc[df.Selected==1, 'Location'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['Sample Number', 'JW ID', 'Plate', 'Column1', 'Blattner ID',
#        'Gene Name', 'Annotation', 'Growth rate in glucose + AA medium',
#        'Selection score (0-3)', 'Selected for pilot', 'Selected',
#        'log10(Mean protein number fraction)', 'log10(Ribosome profiling)',
#        'Location', 'Transported metabolites', 'Metabolite class', 'Class',
#        'Mechanism/specific type', 'Expected direction', 'TCID', 'biocyc link',
#        'Comment', 'Paper', 'Mean protein number fraction',
#        'Std protein number fraction', 'Detected in fraction of all conditions',
#        'Detected in fraction of all C-limit conditions',
#        'Ribosome profiling (Li et al., 2014)'],
#       dtype='object')

# %%
values = df.loc[df.Selected==1, 'Metabolite class'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
values = df.loc[df.Selected==1, 'Class'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100), fontsize = 8)
# Out:
# <Axes: ylabel='count'>

# %%
values = df.loc[df.Selected==1, 'Mechanism/specific type'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
values = df.loc[df.Selected==1, 'Expected direction'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
df.loc[df.Selected==1, 'Metabolite class'].value_counts()
# Out:
# Metabolite class
# Amino acid              32
# Sugar                    7
# Organic acid             6
# Unspecific               5
# Nucleoside               3
# Nucleobase               3
# Other                    3
# Phosphorylated sugar     3
# Peptide                  2
# Drug                     2
# Unknown                  1
# Name: count, dtype: int64

# %% [markdown]
# # Plot expression levels

# %%
df.plot(kind = 'scatter', x = 'Detected in fraction of all conditions', y = 'Mean protein number fraction')
plt.yscale('log')
sns.despine()

# %%
df.plot(kind = 'scatter', x = 'Detected in fraction of all conditions', y = 'Ribosome profiling (Li et al., 2014)')
plt.yscale('log')
sns.despine()

# %%
df.plot(kind = 'scatter', x = 'Detected in fraction of all C-limit conditions', y = 'Ribosome profiling (Li et al., 2014)')
plt.yscale('log')
sns.despine()

# %%
df
# Out:
#      Sample Number    JW ID  Plate Column1 Blattner ID Gene Name  \
# 0               82   JW3491   18.0     A10       b3523      yhjE
# 1               33   JW0108   20.0     C11       b0112      aroP
# 2               50   JW2143   28.0     E10       b2156      lysP
# 3               99   JW1001   28.0      E3       b1015      putP
# 4                5   JW0231    NaN     NaN       b0241      phoE
# ..             ...      ...    ...     ...         ...       ...
# 103             69   JW5619    NaN     NaN       b3709      tnaB
# 104             84   JW3991    NaN     NaN       b4031      xylE
# 105             93   JW2900    NaN     NaN       b2933      cmtA
# 106             97  Unknown    NaN     NaN       b0612      citT
# 107            103   JW4084    NaN     NaN       b4123      dcuB
#
#                                             Annotation  \
# 0        inner membrane protein, predicted transporter
# 1                      aromatic amino acid transporter
# 2                                   lysine transporter
# 3                             proline:sodium symporter
# 4                outer membrane phosphoporin protein E
# ..                                                 ...
# 103             tryptophan transporter of low affinity
# 104                               D-xylose transporter
# 105  predicted fused mannitol-specific PTS enzymes:...
# 106                       citrate:succinate antiporter
# 107  C4-dicarboxylate transporter, anaerobic; DcuS ...
#
#      Growth rate in glucose + AA medium  Selection score (0-3)  \
# 0                                  0.77                    1.0
# 1                                  0.81                    3.0
# 2                                  0.84                    2.0
# 3                                  0.85                    2.0
# 4                                  0.86                    1.0
# ..                                  ...                    ...
# 103                                0.76                    3.0
# 104                                0.77                    1.0
# 105                                0.86                    0.0
# 106                                0.84                    1.0
# 107                                0.77                    1.0
#
#      Selected for pilot  ...  Expected direction  \
# 0                   NaN  ...                 NaN
# 1                   1.0  ...              Import
# 2                   NaN  ...              Import
# 3                   1.0  ...              Import
# 4                   NaN  ...                Both
# ..                  ...  ...                 ...
# 103                 NaN  ...              Import
# 104                 NaN  ...              Import
# 105                 NaN  ...              Import
# 106                 NaN  ...                Both
# 107                 NaN  ...                Both
#
#                                                 TCID  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4    https://tcdb.org/search/result.php?tc=1.b.1.1.2
# ..                                               ...
# 103                                              NaN
# 104                                              NaN
# 105                                              NaN
# 106                                              NaN
# 107                                              NaN
#
#                                         biocyc link  \
# 0    https://biocyc.org/gene?orgid=ECOLI&id=EG12249
# 1    https://biocyc.org/gene?orgid=ECOLI&id=EG10084
# 2    https://biocyc.org/gene?orgid=ECOLI&id=EG11337
# 3    https://biocyc.org/gene?orgid=ECOLI&id=EG10802
# 4    https://biocyc.org/gene?orgid=ECOLI&id=EG10729
# ..                                              ...
# 103  https://biocyc.org/gene?orgid=ECOLI&id=EG11006
# 104  https://biocyc.org/gene?orgid=ECOLI&id=EG11076
# 105  https://biocyc.org/gene?orgid=ECOLI&id=EG11792
# 106    https://biocyc.org/gene?orgid=ECOLI&id=G6338
# 107  https://biocyc.org/gene?orgid=ECOLI&id=EG10006
#
#                                                Comment Paper  \
# 0                                                  NaN   NaN
# 1                                                  NaN   NaN
# 2                                                  NaN   NaN
# 3                                                  NaN   NaN
# 4         Less than 600 Dalton (same as OmpC and OmpF)   NaN
# ..                                                 ...   ...
# 103                        Under catabolite repression   NaN
# 104                                                NaN   NaN
# 105                                                NaN   NaN
# 106  CitT is a putative citrate/succinate antiporte...   NaN
# 107                                                NaN   NaN
#
#     Mean protein number fraction Std protein number fraction  \
# 0                       0.000427                    0.000118
# 1                       0.000252                    0.000054
# 2                       0.000202                    0.000098
# 3                       0.000123                    0.000061
# 4                       0.000038                    0.000070
# ..                           ...                         ...
# 103                     0.000000                    0.000000
# 104                     0.000006                    0.000039
# 105                     0.000000                    0.000000
# 106                     0.000000                    0.000000
# 107                     0.000000                    0.000000
#
#     Detected in fraction of all conditions  \
# 0                                 0.890411
# 1                                 0.931507
# 2                                 0.945205
# 3                                 0.972603
# 4                                 0.602740
# ..                                     ...
# 103                               0.054795
# 104                               0.041096
# 105                               0.000000
# 106                               0.000000
# 107                               0.095890
#
#     Detected in fraction of all C-limit conditions  \
# 0                                         1.000000
# 1                                         1.000000
# 2                                         1.000000
# 3                                         1.000000
# 4                                         0.702703
# ..                                             ...
# 103                                       0.000000
# 104                                       0.027027
# 105                                       0.000000
# 106                                       0.000000
# 107                                       0.000000
#
#     Ribosome profiling (Li et al., 2014)
# 0                              131028500
# 1                               69059770
# 2                               58434590
# 3                               22850580
# 4                                1807160
# ..                                   ...
# 103                                    0
# 104                                    0
# 105                                    0
# 106                                    0
# 107                                    0
#
# [108 rows x 28 columns]
