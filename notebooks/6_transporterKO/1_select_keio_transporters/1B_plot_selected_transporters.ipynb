# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_folder = Path('../../../data')
fn_selected_transporters = data_folder / 'this_project' / '6_transporterKO' / 'B_selected_transporters_with_expression_levels.csv'
df = pd.read_csv(fn_selected_transporters, index_col=0)

# %%
df.tail()
# Out:
#      JW ID Blattner ID Gene Name                            Annotation  \
# 62  JW5735       b4138      dcuA           C4-dicarboxylate antiporter
# 63  JW4038       b4077      gltP  glutamate/aspartate:proton symporter
# 64  JW0009       b0010      satP        acetate/succinate:H+ symporter
# 65  JW2910       b2943      galP               D-galactose transporter
# 66  JW1652       b1660      punC                 predicted transporter
#
#     Growth rate in glucose + AA medium        Location  \
# 62                                0.78  Inner membrane
# 63                                0.86  Inner membrane
# 64                                0.64  Inner membrane
# 65                                0.84  Inner membrane
# 66                                0.76  Inner membrane
#
#                      Transported metabolites Metabolite class  \
# 62  L-aspartate, fumarate, succinate, malate     Organic acid
# 63                  L-aspartate, L-glutamate       Amino acid
# ...

# %%
values = df.loc[:, 'Location'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
df
# Out:
#      JW ID Blattner ID Gene Name  \
# 0   JW0401       b0411       tsx
# 1   JW2203       b2215      ompC
# 2   JW0912       b0929      ompF
# 3   JW1469       b1473      yddG
# 4   JW0590       b0598      cstA
# ..     ...         ...       ...
# 62  JW5735       b4138      dcuA
# 63  JW4038       b4077      gltP
# 64  JW0009       b0010      satP
# 65  JW2910       b2943      galP
# 66  JW1652       b1660      punC
#
#                                            Annotation  \
# 0   nucleoside channel, receptor of phage T6 and c...
# 1                      outer membrane porin protein C
# 2                    outer membrane porin 1a (Ia;b;F)
# 3                        aromatic amino acid exporter
# 4                           carbon starvation protein
# ..                                                ...
# 62                        C4-dicarboxylate antiporter
# 63               glutamate/aspartate:proton symporter
# 64                     acetate/succinate:H+ symporter
# ...

# %%
values = df.loc[:, 'Metabolite class'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
values = df.loc[:, 'Class'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100), fontsize = 8)
# Out:
# <Axes: ylabel='count'>

# %%
values = df.loc[:, 'Mechanism/specific type'].value_counts()
values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %%
values = df.loc[df.Selected==1, 'Type'].value_counts()
ax = values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100), title='')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
values = df.loc[:, 'Expected direction'].value_counts()
ax = values.plot(kind='pie', cmap = 'tab20', autopct = lambda x: '{:.0f}'.format(x*values.sum()/100)) 
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df.loc[:, 'Metabolite class'].value_counts()
# Out:
# Metabolite class
# Amino acid              32
# Sugar                    7
# Organic acid             6
# Unspecific               5
# Nucleoside               3
# Phosphorylated sugar     3
# Other                    3
# Nucleobase               3
# Drug                     2
# Peptide                  2
# Unknown                  1
# Name: count, dtype: int64

# %% [markdown]
# # Plot expression levels

# %%
df.plot(kind = 'scatter', x = 'Detected in fraction of all conditions', y = 'Mean protein number fraction')
plt.yscale('log')
sns.despine()

# %%
df.plot(kind = 'scatter', x = 'Detected in fraction of all conditions', y = 'Ribosome profiling (Li et al., 2014)')
plt.yscale('log')
sns.despine()

# %%
df.plot(kind = 'scatter', x = 'Detected in fraction of all C-limit conditions', y = 'Ribosome profiling (Li et al., 2014)')
plt.yscale('log')
sns.despine()
